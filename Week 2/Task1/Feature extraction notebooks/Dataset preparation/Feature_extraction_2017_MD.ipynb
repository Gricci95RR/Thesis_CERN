# 34    0  27.818136  3.448984  1.410795e+01   0.061716    3.847531      1
# 35    1  27.818136  3.640595  1.410795e+01   0.061716    3.847531      1
# 36    0   1.360621  6.323346  1.731643e-14  -1.000000 -121.730339      0
# 37    1   1.360621  5.925266  1.731643e-14  -1.000000 -121.730339      0
# 38    1   5.833371  3.359340  5.820387e+00   0.132979    4.573998      1
# 39    0   5.475250  4.356645  7.420517e+00   0.638753    5.090352      1
# 40    1   5.475250  3.473863  7.420517e+00   0.638753    5.090352      1
# 41    0   2.832239  5.363871  3.913254e+00   0.092820    6.632955      0
# 42    1   2.832239  4.965791  3.913254e+00   0.092820    6.632955      0
# 43    0   4.680641  4.233140  5.852063e+00   0.036113    0.381015      1
# 44    0   1.388707  6.405003  1.315146e+00   3.890892    3.934071      0
# 45    1   1.388707  6.006923  1.315146e+00   3.890892    3.934071      0

# %%
# Add a column to the dataframe that represents the collimator type (TCP, TCSG, TCLA, TCT, TCDQ)
TCP_features["collimator_type"] = "TCP"
# Add a column to the dataframe that represents the beam type type (ION or PROTON)
TCP_features["beam_type"] = "PROTON"
# Add a column to the dataframe that represents the beam state (Injection (I) or Flat top (FT))
TCP_features["beam_state"] = ""

# %%
# Load of all TCSG features
path = r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/Auto_data/2017_MD/*_TCSG.*_Align_features'
all_rec = iglob(path, recursive=True)     
dataframes = (pd.read_csv(f) for f in all_rec)
TCSG_features = pd.concat(dataframes, ignore_index=True)
TCSG_features
# Add a column to the dataframe that represents the collimator type (TCP, TCSG, TCLA, TCT, TCDQ)
TCSG_features["collimator_type"] = "TCSG"
# Add a column to the dataframe that represents the beam type type (ION or PROTON)
TCSG_features["beam_type"] = "PROTON"
# Add a column to the dataframe that represents the beam state (Injection (I) or Flat top (FT))
TCSG_features["beam_state"] = ""
TCSG_features
# Out:
#     jaw     height  position    decay_a    decay_b   decay_c  spike  \
# 0     0   2.160268  3.136375   1.606817   0.356618  1.086276      0
# 1     1   2.160268  3.817893   1.606817   0.356618  1.086276      0
# 2     0   6.479781  2.969472   5.664842   0.184179  2.526871      1
# 3     0  10.679000  4.040842   9.436674   0.221326  4.823756      1
# 4     1  10.679000  2.843764   9.436674   0.221326  4.823756      1
# 5     0   4.480779  3.011198   3.694836   0.135627  2.014730      1
# 6     0  47.551573  3.861000  49.002202   0.123570  5.756739      1
# 7     1   3.115063  3.692716   2.650879  21.496977  2.417121      0
# 8     1   2.925095  3.664899   1.957781   0.107650  2.617569      0
# 9     1   5.321500  3.650990   3.297849   0.103029  3.350276      1
# 10    0   4.766389  3.080740   3.551053   0.123560  1.868239      1
# 11    1   4.766389  3.762259   3.551053   0.123560  1.868239      1
# 12    1   5.363316  2.686402   4.176195   0.118447  6.264377      1
#
#    collimator_type beam_type beam_state
# 0             TCSG    PROTON
# 1             TCSG    PROTON
# 2             TCSG    PROTON
# 3             TCSG    PROTON
# 4             TCSG    PROTON
# 5             TCSG    PROTON
# 6             TCSG    PROTON
# 7             TCSG    PROTON
# 8             TCSG    PROTON
# 9             TCSG    PROTON
# 10            TCSG    PROTON
# 11            TCSG    PROTON
# 12            TCSG    PROTON

# %%
# Load of all TCLA features
path = r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/Auto_data/2017_MD/*_TCLA.*_Align_features'
all_rec = iglob(path, recursive=True)     
dataframes = (pd.read_csv(f) for f in all_rec)
TCLA_features = pd.concat(dataframes, ignore_index=True)
TCLA_features
# Add a column to the dataframe that represents the collimator type (TCP, TCSG, TCLA, TCT, TCDQ)
TCLA_features["collimator_type"] = "TCLA"
# Add a column to the dataframe that represents the beam type type (ION or PROTON)
TCLA_features["beam_type"] = "PROTON"
# Add a column to the dataframe that represents the beam state (Injection (I) or Flat top (FT))
TCLA_features["beam_state"] = ""
TCLA_features
# Out:
#     jaw     height  position       decay_a    decay_b       decay_c  spike  \
# 0     0   5.453863  3.567789  2.510854e-14  -1.000000  3.905125e+08      0
# 1     1   7.390312  3.806109  6.658836e+00   0.187559  4.999317e+00      1
# 2     0   3.281078  3.778072  2.079416e+00   1.232135  3.504680e+00      0
# 3     1   3.281078  3.890222  2.079416e+00   1.232135  3.504680e+00      0
# 4     0   0.717000  6.974362  7.119830e-01   0.468739  3.617794e-01      0
# 5     1   0.717000  7.086513  7.119830e-01   0.468739  3.617794e-01      0
# 6     0   1.068474  3.974335  9.198571e-01  27.531296  1.433143e+00      0
# 7     1   1.068474  4.086486  9.198571e-01  27.531296  1.433143e+00      0
# 8     0  10.441976  3.750034  8.139968e+00   0.381717  4.517820e+00      1
# 9     1  10.441976  3.862185  8.139968e+00   0.381717  4.517820e+00      1
# 10    0  54.604665  3.518724  5.203767e+01   1.562638  7.626137e+00      1
# 11    0   0.735805  9.848220  5.276015e-01   0.291422  3.553851e-01      0
# 12    1   0.735805  9.960371  5.276015e-01   0.291422  3.553851e-01      0
#
#    collimator_type beam_type beam_state
# 0             TCLA    PROTON
# 1             TCLA    PROTON
# 2             TCLA    PROTON
# 3             TCLA    PROTON
# 4             TCLA    PROTON
# 5             TCLA    PROTON
# 6             TCLA    PROTON
# 7             TCLA    PROTON
# 8             TCLA    PROTON
# 9             TCLA    PROTON
# 10            TCLA    PROTON
# 11            TCLA    PROTON
# 12            TCLA    PROTON

# %%
# Load of all TCT features

path = r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/Auto_data/2017_MD/*_TCT*_Align_features'
all_rec = iglob(path, recursive=True)     
dataframes = (pd.read_csv(f) for f in all_rec)
TCT_features = pd.concat(dataframes, ignore_index=True)
TCT_features
# Add a column to the dataframe that represents the collimator type (TCP, TCSG, TCLA, TCT, TCDQ)
TCT_features["collimator_type"] = "TCT"
# Add a column to the dataframe that represents the beam type type (ION or PROTON)
TCT_features["beam_type"] = "PROTON"
# Add a column to the dataframe that represents the beam state (Injection (I) or Flat top (FT))
TCT_features["beam_state"] = " "
TCT_features

"""
# No TCDQ features
path = r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/Auto_data/2017_MD/*_TCDQ.*_Align_features'
all_rec = iglob(path, recursive=True)     
dataframes = (pd.read_csv(f) for f in all_rec)
TCDQ_features = pd.concat(dataframes, ignore_index=True)
TCDQ_features
# Add a column to the dataframe that represents the collimator type (TCP, TCSG, TCLA, TCT, TCDQ)
TCDQ_features["collimator_type"] = "TCDQ"
# Add a column to the dataframe that represents the beam type type (ION or PROTON)
TCDQ_features["beam_type"] = "PROTON"
# Add a column to the dataframe that represents the beam state (Injection (I) or Flat top (FT))
TCDQ_features["beam_state"] = " "
TCDQ_features
"""
# Out:
# '\n# No TCDQ features\npath = r\'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/Auto_data/2017_MD/*_TCDQ.*_Align_features\'\nall_rec = iglob(path, recursive=True)     \ndataframes = (pd.read_csv(f) for f in all_rec)\nTCDQ_features = pd.concat(dataframes, ignore_index=True)\nTCDQ_features\n# Add a column to the dataframe that represents the collimator type (TCP, TCSG, TCLA, TCT, TCDQ)\nTCDQ_features["collimator_type"] = "TCDQ"\n# Add a column to the dataframe that represents the beam type type (ION or PROTON)\nTCDQ_features["beam_type"] = "PROTON"\n# Add a column to the dataframe that represents the beam state (Injection (I) or Flat top (FT))\nTCDQ_features["beam_state"] = " "\nTCDQ_features\n'

# %%
# Merge all dataframe in one
frames = [TCP_features, TCSG_features, TCLA_features]
MD_2017_dataframe = pd.concat(frames)
MD_2017_dataframe.to_csv("2017_MD_dataframe.csv")
