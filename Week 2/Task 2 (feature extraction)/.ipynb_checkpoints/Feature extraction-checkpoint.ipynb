# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import iglob

# %%
# read of f_col_info
f_col_info = pd.read_csv(r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/col_info/2018/f_col_info.csv')
# read of i_col_info
i_col_info = pd.read_csv(r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/col_info/2018/i_col_info.csv')

# %%
# read of dataset
dataset = pd.read_csv(r'/Users/gianmarcoricci/Documents/GitHub/Thesis_CERN/Week 2/Task 1 (Data preparation and plots)/Auto_dataset4.csv')
del dataset['Unnamed: 0']
dataset
# Out:
#       jaw      height   position     decay_a    decay_b   decay_c  spike  \
# 0       0    5.910913   5.248969    6.235078   0.344805  0.865752      1
# 1       1    2.013513   4.100928    2.026613   2.851484  0.868502      0
# 2       0   31.565092   5.502972   27.247661   0.476436  3.484360      1
# 3       1   31.565092   4.393772   27.247661   0.476436  3.484360      1
# 4       1    7.030556   3.333658    6.997113   0.052134  2.340324      1
# ...   ...         ...        ...         ...        ...       ...    ...
# 8788    1   26.972851  13.343164   25.949200   0.305902  3.644874      1
# 8789    0   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8790    1   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8791    0  141.277962  11.376518  136.430710  43.774418  6.016290      1
# 8792    1  141.277962  11.376518  136.430710  43.774418  6.016290      1
#
#      collimator_type beam_type beam_state
# 0                TCP    PROTON          I
# ...
