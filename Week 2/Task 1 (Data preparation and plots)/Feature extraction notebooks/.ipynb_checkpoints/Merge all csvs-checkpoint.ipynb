# %%
import seaborn as sns
from glob import iglob
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/2017_MD_dataframe.csv')
df2 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/2018_MD3_dataframe.csv')
df3 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/2018_MD4_dataframe.csv')
df4 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/I_test_2018_dataframe.csv')
df5 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/II_test_2018_dataframe.csv')
df6 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/III_inj_2018_dataframe.csv')
df7 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/ION_dataframe.csv')
df8 = pd.read_csv (r'/Users/gianmarcoricci/Desktop/Dataframes/IV_flat_2018_dataframe.csv')

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8]
tot = pd.concat(frames)
tot.to_csv("Auto_dataset.csv")
