# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/gianmarcoricci/Documents/GitHub/Thesis_CERN/Week 2/Task 1 (Data preparation and plots)/Auto_dataset4.csv')
del df['Unnamed: 0']

# %%
df
# Out:
#       jaw      height   position     decay_a    decay_b   decay_c  spike  \
# 0       0    5.910913   5.248969    6.235078   0.344805  0.865752      1
# 1       1    2.013513   4.100928    2.026613   2.851484  0.868502      0
# 2       0   31.565092   5.502972   27.247661   0.476436  3.484360      1
# 3       1   31.565092   4.393772   27.247661   0.476436  3.484360      1
# 4       1    7.030556   3.333658    6.997113   0.052134  2.340324      1
# ...   ...         ...        ...         ...        ...       ...    ...
# 8857    1   26.972851  13.343164   25.949200   0.305902  3.644874      1
# 8858    0   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8859    1   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8860    0  141.277962  11.376518  136.430710  43.774418  6.016290      1
# 8861    1  141.277962  11.376518  136.430710  43.774418  6.016290      1
#
#      collimator_type beam_type beam_state
# 0                TCP    PROTON          I
# ...

# %%
ax = sns.countplot(x = "beam_state", data = df, palette = "Set1")
ax.set(xlabel='Beam State', ylabel='Count')
plt.show()

# %%
ax2 = sns.countplot(x = "beam_type", data = df, palette = "Set2")
ax2.set(xlabel='Beam Type', ylabel='Count')
plt.show()

# %%
ax3 = sns.countplot(x = "collimator_type", data = df, palette = "Set3")
ax3.set(xlabel='Collimator Type', ylabel='Count')
plt.show()

# %%
ax3 = sns.countplot(x = "collimator_type", data = df, palette = "Set1", hue="beam_type")
ax3.set(xlabel='Collimator Type', ylabel='Count')
plt.show()

# %%
ax3 = sns.countplot(x = "collimator_type", data = df, palette = "Set2", hue="beam_state")
ax3.set(xlabel='Collimator Type', ylabel='Count')
plt.show()

# %%
sns.pairplot(df, palette="husl");

# %%
sns.pairplot(df, palette="husl", corner=True);

# %%
g = sns.pairplot(df, diag_kind="kde", corner = True)

# %%
# Plot Correlation Heatmap
plt.figure(figsize=(15, 8))
correlation = df.corr(method="spearman")
heatmap = sns.heatmap(correlation,vmin=-1, vmax=1, annot=True);
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
sns.relplot(x="decay_a", y="height", col="beam_type", data=df);
sns.relplot(x="decay_a", y="height", col="collimator_type", data=df);

# %%
sns.relplot(x="decay_c", y="height", col="beam_type", data=df);
sns.relplot(x="decay_c", y="height", col="collimator_type", data=df);

# %%
sns.relplot(x="decay_c", y="decay_a", col="beam_type", data=df);
sns.relplot(x="decay_c", y="decay_a", col="collimator_type", data=df);

# %%
sns.relplot(x="height", y="spike", col="beam_type", data=df);
sns.relplot(x="height", y="spike", col="collimator_type", data=df);

# %%
sns.relplot(x="decay_a", y="spike", col="beam_type", data=df);
sns.relplot(x="decay_a", y="spike", col="collimator_type", data=df);

# %%
g = sns.pairplot(df, kind="reg",corner = True)

# %%
g = sns.PairGrid(df, hue="beam_type")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(df, hue="collimator_type")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()
