# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/Users/gianmarcoricci/Desktop/Beam State Analysis/Results/Results.txt')

# %%
df
# Out:
#     Precision Model Beam State
# 0     0.97160    DT         FT
# 1     0.97710    DT          I
# 2     0.97630   GBC         FT
# 3     0.98470   GBC          I
# 4     0.97990    LR         FT
# 5     0.96960    LR          I
# 6     0.99190    NN         FT
# 7     0.97910    NN          I
# 8     0.97630    RF         FT
# 9     0.98480    RF          I
# 10    0.97600   SVM         FT
# 11    0.97065   SVM          I

# %%
sns.set(style="whitegrid")
sns.barplot(x = 'Model', y = 'Precision',hue = 'Beam State', data = df,
            palette = 'hls',
            capsize = 0.05,             
            saturation = 8,             
            errcolor = 'gray', errwidth = 2,  
            ci = 'sd'
            )
