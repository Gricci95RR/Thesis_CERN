# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/gianmarcoricci/Documents/GitHub/Thesis_CERN/Dataset/Auto_2018_dataset_NO_TCL.csv').drop(['Unnamed: 0'],axis=1)

# %%
df
# Out:
#       jaw      height   position     decay_a    decay_b   decay_c  spike  \
# 0       0    5.910913   5.248969    6.235078   0.344805  0.865752      1
# 1       1    2.013513   4.100928    2.026613   2.851484  0.868502      0
# 2       0   31.565092   5.502972   27.247661   0.476436  3.484360      1
# 3       1   31.565092   4.393772   27.247661   0.476436  3.484360      1
# 4       1    7.030556   3.333658    6.997113   0.052134  2.340324      1
# ...   ...         ...        ...         ...        ...       ...    ...
# 8224    1   26.972851  13.343164   25.949200   0.305902  3.644874      1
# 8225    0   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8226    1   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8227    0  141.277962  11.376518  136.430710  43.774418  6.016290      1
# 8228    1  141.277962  11.376518  136.430710  43.774418  6.016290      1
#
#      collimator_type beam_type beam_state
# 0                TCP    PROTON          I
# ...

# %%
df.describe()
# Out:
#                jaw        height     position       decay_a      decay_b  \
# count  8229.000000   8229.000000  8229.000000  8.229000e+03  8229.000000
# mean      0.485357    209.388097     5.066240 -7.946965e+01     8.871694
# std       0.499816   1234.286658     5.015499  2.153022e+04    76.795354
# min       0.000000 -34333.565640     0.008669 -1.107229e+06    -0.257768
# 25%       0.000000      4.186069     2.781423  4.097452e+00     0.159997
# 50%       0.000000     13.260022     4.015813  1.197584e+01     0.356472
# 75%       1.000000     75.292451     5.384122  6.844061e+01     0.768687
# max       1.000000  34462.231490    70.058101  8.578348e+05  4738.231430
#
#             decay_c        spike
# count  8.229000e+03  8229.000000
# mean   2.934314e+02     0.704946
# std    2.150632e+04     0.456095
# min   -8.572518e+05     0.000000
# 25%    1.257429e+00     0.000000
# 50%    3.274595e+00     1.000000
# 75%    9.160174e+00     1.000000
# max    1.107700e+06     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8229 entries, 0 to 8228
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   jaw              8229 non-null   int64
#  1   height           8229 non-null   float64
#  2   position         8229 non-null   float64
#  3   decay_a          8229 non-null   float64
#  4   decay_b          8229 non-null   float64
#  5   decay_c          8229 non-null   float64
#  6   spike            8229 non-null   int64
#  7   collimator_type  8229 non-null   object
#  8   beam_type        8229 non-null   object
#  9   beam_state       8229 non-null   object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 643.0+ KB

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %% [markdown]
# Dataset has no missing values.

# %%
a4_dims = (28, 12)
sns.set_style("darkgrid")
fig, (ax0,ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols=7, sharey=False,figsize=a4_dims)
sns.stripplot(x='beam_state', y='jaw', ax=ax0,data=df)
sns.stripplot(x='beam_state', y='height', ax=ax1,data=df)
sns.stripplot(x='beam_state', y='position', ax=ax2,data=df)
sns.stripplot(x='beam_state', y='decay_a', ax=ax3,data=df)
sns.stripplot(x='beam_state', y='decay_b', ax=ax4,data=df)
sns.stripplot(x='beam_state', y='decay_c', ax=ax5,data=df)
sns.stripplot(x='beam_state', y='spike', ax=ax6,data=df)

# %%
a4_dims = (28, 12)
sns.set_style("darkgrid")
fig, (ax0,ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols=7, sharey=False,figsize=a4_dims)
sns.violinplot(x='beam_state', y='jaw', ax=ax0,data=df)
sns.violinplot(x='beam_state', y='height', ax=ax1,data=df)
sns.violinplot(x='beam_state', y='position', ax=ax2,data=df)
sns.violinplot(x='beam_state', y='decay_a', ax=ax3,data=df)
sns.violinplot(x='beam_state', y='decay_b', ax=ax4,data=df)
sns.violinplot(x='beam_state', y='decay_c', ax=ax5,data=df)
sns.violinplot(x='beam_state', y='spike', ax=ax6,data=df)

# %%
a4_dims = (30, 12)
sns.set_style("darkgrid")
fig, (ax0,ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols=7, sharey=False,figsize=a4_dims)
sns.pointplot(x='beam_state', y='jaw', ax=ax0,data=df)
sns.pointplot(x='beam_state', y='height', ax=ax1,data=df)
sns.pointplot(x='beam_state', y='position', ax=ax2,data=df)
sns.pointplot(x='beam_state', y='decay_a', ax=ax3,data=df)
sns.pointplot(x='beam_state', y='decay_b', ax=ax4,data=df)
sns.pointplot(x='beam_state', y='decay_c', ax=ax5,data=df)
sns.pointplot(x='beam_state', y='spike', ax=ax6,data=df)

# %% [markdown]
# ### Detection and Removing the Outliers

# %%
df_numerical = df.drop(['spike', 'collimator_type', 'beam_type', 'beam_state','jaw'],axis=1) # numerical dataframe
df_categorical = df.drop(['height','position','decay_a','decay_b','decay_c'],axis=1) # categorical dataframe

# %%
Q1 = df_numerical.quantile(0.25)
Q3 = df_numerical.quantile(0.75)
IQR = Q3 - Q1
idx = ~((df_numerical < (Q1 - 1.5 * IQR)) | (df_numerical > (Q3 + 1.5 * IQR))).any(axis=1) # index of rows to keep and discard
df_cleaned = pd.concat([df_numerical.loc[idx], df_categorical.loc[idx]], axis=1)

# %%
a4_dims = (28, 12)
sns.set_style("darkgrid")
fig, (ax0,ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols=7, sharey=False,figsize=a4_dims)
sns.stripplot(x='beam_state', y='jaw', ax=ax0,data=df_cleaned)
sns.stripplot(x='beam_state', y='height', ax=ax1,data=df_cleaned)
sns.stripplot(x='beam_state', y='position', ax=ax2,data=df_cleaned)
sns.stripplot(x='beam_state', y='decay_a', ax=ax3,data=df_cleaned)
sns.stripplot(x='beam_state', y='decay_b', ax=ax4,data=df_cleaned)
sns.stripplot(x='beam_state', y='decay_c', ax=ax5,data=df_cleaned)
sns.stripplot(x='beam_state', y='spike', ax=ax6,data=df_cleaned)

# %%
a4_dims = (28, 12)
sns.set_style("darkgrid")
fig, (ax0,ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols=7, sharey=False,figsize=a4_dims)
sns.violinplot(x='beam_state', y='jaw', ax=ax0,data=df_cleaned)
sns.violinplot(x='beam_state', y='height', ax=ax1,data=df_cleaned)
sns.violinplot(x='beam_state', y='position', ax=ax2,data=df_cleaned)
sns.violinplot(x='beam_state', y='decay_a', ax=ax3,data=df_cleaned)
sns.violinplot(x='beam_state', y='decay_b', ax=ax4,data=df_cleaned)
sns.violinplot(x='beam_state', y='decay_c', ax=ax5,data=df_cleaned)
sns.violinplot(x='beam_state', y='spike', ax=ax6,data=df_cleaned)

# %%
a4_dims = (30, 12)
sns.set_style("darkgrid")
fig, (ax0,ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(ncols=7, sharey=False,figsize=a4_dims)
sns.pointplot(x='beam_state', y='jaw', ax=ax0,data=df_cleaned)
sns.pointplot(x='beam_state', y='height', ax=ax1,data=df_cleaned)
sns.pointplot(x='beam_state', y='position', ax=ax2,data=df_cleaned)
sns.pointplot(x='beam_state', y='decay_a', ax=ax3,data=df_cleaned)
sns.pointplot(x='beam_state', y='decay_b', ax=ax4,data=df_cleaned)
sns.pointplot(x='beam_state', y='decay_c', ax=ax5,data=df_cleaned)
sns.pointplot(x='beam_state', y='spike', ax=ax6,data=df_cleaned)

# %%
a4_dims = (30, 12)
sns.set_style("darkgrid")
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=5, sharey=False,figsize=a4_dims)
sns.boxplot(x='beam_state', y='height', ax=ax1,data=df_cleaned)
sns.boxplot(x='beam_state', y='position', ax=ax2,data=df_cleaned)
sns.boxplot(x='beam_state', y='decay_a', ax=ax3,data=df_cleaned)
sns.boxplot(x='beam_state', y='decay_b', ax=ax4,data=df_cleaned)
sns.boxplot(x='beam_state', y='decay_c', ax=ax5,data=df_cleaned)

# %%
a4_dims = (30, 12)
sns.set_style("darkgrid")
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=5, sharey=False,figsize=a4_dims)
sns.histplot(df_cleaned, x="height", hue="beam_state",element="step",ax=ax1)
sns.histplot(df_cleaned, x="position", hue="beam_state",element="step",ax=ax2)
sns.histplot(df_cleaned, x="decay_a", hue="beam_state",element="step",ax=ax3)
sns.histplot(df_cleaned, x="decay_b", hue="beam_state",element="step",ax=ax4)
sns.histplot(df_cleaned, x="decay_c", hue="beam_state",element="step",ax=ax5)

# %%
a4_dims = (30, 12)
sns.set_style("darkgrid")
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(ncols=5, sharey=False,figsize=a4_dims)
sns.kdeplot(data=df_cleaned, x="height", hue="beam_state",ax=ax1)
sns.kdeplot(data=df_cleaned, x="position", hue="beam_state",ax=ax2)
sns.kdeplot(data=df_cleaned, x="decay_a", hue="beam_state",ax=ax3)
sns.kdeplot(data=df_cleaned, x="decay_b", hue="beam_state",ax=ax4)
sns.kdeplot(data=df_cleaned, x="decay_c", hue="beam_state",ax=ax5)
