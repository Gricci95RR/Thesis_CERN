# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/gianmarcoricci/Documents/GitHub/Thesis_CERN/Dataset/2016_dataset.csv')

# %%
df
# Out:
#       jaw       height   position  Maximum value      decay_a     decay_b  \
# 0       0     1.093440  13.459630          1.448     1.101109   33.502892
# 1       1     0.804907  17.715508          1.086     0.821299   18.891463
# 2       1     6.123438   7.083522          7.240     7.189065    0.386156
# 3       1    11.685360   6.898339         11.946    11.690968  100.599839
# 4       0     4.350154  12.288937          4.706     4.327683   34.544517
# ...   ...          ...        ...            ...          ...         ...
# 1647    1  1646.446172   2.406066       1668.820  1155.805113    0.144723
# 1648    1    15.984110   2.716241         17.738    14.164563    0.401771
# 1649    0    10.288559   2.716241         11.584     7.441587    0.127553
# 1650    1     6.838180   2.749775          8.326     6.030267    0.153555
# 1651    0  3064.583210   2.338998       3104.510  2700.238735    0.198030
#
#          decay_c  spike collimator_type beam_type beam_state
# 0       0.346891      0           TCTPV    PROTON          I
# 1       0.264701      0           TCLIB    PROTON          I
# 2       0.931550      0            TCSG    PROTON          I
# 3       0.255032      0           TCTPH    PROTON          I
# 4       0.378317      0            TCSG    PROTON          I
# ...          ...    ...             ...       ...        ...
# 1647   79.128566      1            TCLA    PROTON         FT
# 1648    1.757956      1            TCLA    PROTON         FT
# 1649    1.848155      1            TCLA    PROTON         FT
# 1650    1.450398      1            TCLA    PROTON         FT
# 1651  112.864074      1            TCLA    PROTON         FT
#
# [1652 rows x 11 columns]

# %%
df.describe()
# Out:
#                jaw        height     position  Maximum value       decay_a  \
# count  1652.000000   1652.000000  1652.000000    1652.000000   1652.000000
# mean      0.501211    284.396522    12.391096     290.379792    246.424618
# std       0.500150   1660.534068    11.140996    1673.863319   1585.495366
# min       0.000000      0.455633   -18.516014       0.724000 -12929.817869
# 25%       0.000000      1.136224     5.015866       1.448000      1.133139
# 50%       1.000000      1.507911     9.810845       1.810000      1.507830
# 75%       1.000000     14.975416    15.056872      16.380500     11.822340
# max       1.000000  25922.414504    79.716982   25969.900000  23384.347432
#
#            decay_b       decay_c        spike
# count  1652.000000   1652.000000  1652.000000
# mean     18.184924      5.273586     0.282688
# std      24.666001    638.920234     0.450442
# min      -0.000001 -22383.999491     0.000000
# 25%       0.250418      0.308214     0.000000
# 50%      19.085130      0.365572     0.000000
# 75%      25.909369      1.099387     1.000000
# max     481.823408  12941.648149     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1652 entries, 0 to 1651
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   jaw              1652 non-null   int64
#  1   height           1652 non-null   float64
#  2   position         1652 non-null   float64
#  3   Maximum value    1652 non-null   float64
#  4   decay_a          1652 non-null   float64
#  5   decay_b          1652 non-null   float64
#  6   decay_c          1652 non-null   float64
#  7   spike            1652 non-null   int64
#  8   collimator_type  1652 non-null   object
#  9   beam_type        1652 non-null   object
#  10  beam_state       1652 non-null   object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 142.1+ KB

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %% [markdown]
# Dataset has no missing values.

# %%
g = sns.PairGrid(df, hue="beam_state")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %% [markdown]
# **Stripplot** is a scatterplot where one variable is categorical.

# %%
sns.stripplot(x='beam_state', y='height', 
            data=df,jitter='0.25')

# %% [markdown]
# From this image I can see that some values at injection are negative

# %%
sns.stripplot(x='beam_state', y='position', 
            data=df,jitter='0.25')

# %%
sns.stripplot(x='beam_state', y='decay_a', 
            data=df,jitter='0.25')

# %% [markdown]
# Same distribution for "decay_a" apart for some outliers at injection.

# %%
sns.stripplot(x='beam_state', y='decay_b', 
            data=df,jitter='0.25')

# %%
sns.stripplot(x='beam_state', y='decay_c', 
            data=df,jitter='0.25')

# %% [markdown]
# **Violin Plot** draws a combination of boxplot and kernel density estimate

# %%
sns.catplot(x='beam_state', y='height', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='position', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='decay_a', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='decay_b', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='decay_c', 
            data=df,jitter='0.25',kind='violin')

# %% [markdown]
# A **point plot** represents an estimate of central tendency for a numeric variable by the position of scatter plot
# points and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(x='beam_state', y='height', 
            data=df,jitter='0.25')

# %% [markdown]
# Central tendency of values of the feature "height" is higher at FT

# %%
sns.pointplot(x='beam_state', y='position', 
            data=df, jitter='0.25')

# %% [markdown]
# Central tendency of values of the feature "position" is higher at FT

# %%
sns.pointplot(x='beam_state', y='decay_a', 
            data=df, jitter='0.25')

# %% [markdown]
# Central tendency of values of the feature "decay_a" is higher at FT

# %%
sns.pointplot(x='beam_state', y='decay_b', 
            data=df, jitter='0.25')

# %% [markdown]
# Central tendency of values of the feature "decay_b" is higher at Injection

# %%
sns.pointplot(x='beam_state', y='decay_c', 
            data=df, jitter='0.25')

# %% [markdown]
# Central tendency of values of the feature "decay_c" is about the same

# %% [markdown]
# **Distributions** between the features when they are splitted

# %%
inj_dataframe = df.loc[df['beam_state'] == 'I']
ft_dataframe = df.loc[df['beam_state'] == 'FT']

# %%
sns.kdeplot(inj_dataframe.height, shade=True);
sns.kdeplot(ft_dataframe.height, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: height')
# Out:
# Text(0.5, 1.0, 'Feature: height')

# %% [markdown]
# The feature "height" at Flat Top is right skewed/positively skewed.

# %%
sns.kdeplot(inj_dataframe.position, shade=True);
sns.kdeplot(ft_dataframe.position, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: position')
# Out:
# Text(0.5, 1.0, 'Feature: position')

# %% [markdown]
# The distributions for the feature "position" are different. At Flat top there are some negative values.

# %%
sns.kdeplot(inj_dataframe.decay_a, shade=True);
sns.kdeplot(ft_dataframe.decay_a, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: decay_a')
# Out:
# Text(0.5, 1.0, 'Feature: decay_a')

# %% [markdown]
# At FT the values of the feature "decay_a" are all around 0, while at injection are more distributed in the x-axis

# %%
sns.kdeplot(inj_dataframe.decay_b, shade=True);
sns.kdeplot(ft_dataframe.decay_b, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: decay_b')
# Out:
# Text(0.5, 1.0, 'Feature: decay_b')

# %% [markdown]
# The distribution for the feature "decay_b is about the same and they are both right skewed/positively skewed."

# %%
sns.kdeplot(inj_dataframe.decay_c, shade=True);
sns.kdeplot(ft_dataframe.decay_c, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: decay_c')
# Out:
# Text(0.5, 1.0, 'Feature: decay_c')

# %% [markdown]
# At Injection the values of the feature "decay_c" are all around 0, while at Flat Top are distributed in the x-axis

# %%
sns.kdeplot(inj_dataframe.jaw, shade=True);
sns.kdeplot(ft_dataframe.jaw, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: jaw')
# Out:
# Text(0.5, 1.0, 'Feature: jaw')

# %% [markdown]
# A **box plot** (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(y=df['jaw'],x=df["beam_state"])

# %%
sns.boxplot(y=df['height'],x=df["beam_state"])

# %%
sns.boxplot(y=df['position'],x=df["beam_state"])

# %%
sns.boxplot(y=df['decay_a'],x=df["beam_state"])

# %%
sns.boxplot(y=df['decay_b'],x=df["beam_state"])

# %%
sns.boxplot(y=df['decay_c'],x=df["beam_state"])

# %%
sns.boxplot(y=df['spike'],x=df["beam_state"])

# %% [markdown]
# Except "jaw" and "spike" all other features columns shows outliers.
