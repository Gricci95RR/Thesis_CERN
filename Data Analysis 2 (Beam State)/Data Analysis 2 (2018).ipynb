# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/gianmarcoricci/Documents/GitHub/Thesis_CERN/2018 Dataset Preparation/Auto_2018_dataset_.csv').drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#       jaw      height   position     decay_a    decay_b   decay_c  spike  \
# 0       0    5.910913   5.248969    6.235078   0.344805  0.865752      1
# 1       1    2.013513   4.100928    2.026613   2.851484  0.868502      0
# 2       0   31.565092   5.502972   27.247661   0.476436  3.484360      1
# 3       1   31.565092   4.393772   27.247661   0.476436  3.484360      1
# 4       1    7.030556   3.333658    6.997113   0.052134  2.340324      1
# ...   ...         ...        ...         ...        ...       ...    ...
# 8857    1   26.972851  13.343164   25.949200   0.305902  3.644874      1
# 8858    0   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8859    1   15.465093  15.137477   15.791677   0.628352  1.243694      1
# 8860    0  141.277962  11.376518  136.430710  43.774418  6.016290      1
# 8861    1  141.277962  11.376518  136.430710  43.774418  6.016290      1
#
#      collimator_type beam_type beam_state
# 0                TCP    PROTON          I
# ...

# %%
df.describe()
# Out:
#                jaw        height     position       decay_a      decay_b  \
# count  8862.000000   8862.000000  8862.000000  8.862000e+03  8862.000000
# mean      0.486685    202.551464     5.036551 -1.026595e+02    11.676079
# std       0.499851   1192.359487     4.867693  2.088429e+04    82.674051
# min       0.000000 -34333.565640     0.008669 -1.107229e+06    -1.000000
# 25%       0.000000      4.435817     2.808592  4.270659e+00     0.159592
# 50%       0.000000     13.864039     4.058178  1.241482e+01     0.366365
# 75%       1.000000     75.975808     5.437037  6.813898e+01     0.844922
# max       1.000000  34462.231490    70.058101  8.578348e+05  4738.231430
#
#             decay_c        spike
# count  8.862000e+03  8862.000000
# mean   4.437552e+04     0.707967
# std    4.148339e+06     0.454723
# min   -8.572518e+05     0.000000
# 25%    1.310067e+00     0.000000
# 50%    3.471872e+00     1.000000
# 75%    9.456244e+00     1.000000
# max    3.905125e+08     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8862 entries, 0 to 8861
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   jaw              8862 non-null   int64
#  1   height           8862 non-null   float64
#  2   position         8862 non-null   float64
#  3   decay_a          8862 non-null   float64
#  4   decay_b          8862 non-null   float64
#  5   decay_c          8862 non-null   float64
#  6   spike            8862 non-null   int64
#  7   collimator_type  8862 non-null   object
#  8   beam_type        8862 non-null   object
#  9   beam_state       8862 non-null   object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 692.5+ KB

# %%
g = sns.PairGrid(df, hue="beam_state")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
sns.pairplot(df, hue="beam_state");

# %%
# Stripplot is a scatterplot where one variable is categorical.

# %%
sns.catplot(x='beam_state', y='height', 
            data=df,jitter='0.25',legend=True)

# %%
sns.catplot(x='beam_state', y='position', 
            data=df,jitter='0.25')

# %%
sns.catplot(x='beam_state', y='decay_a', 
            data=df,jitter='0.25')

# %%
sns.catplot(x='beam_state', y='decay_b', 
            data=df,jitter='0.25')

# %%
sns.catplot(x='beam_state', y='decay_c', 
            data=df,jitter='0.25')

# %%
# Violin Plot draws a combination of boxplot and kernel density estimate

# %%
sns.catplot(x='beam_state', y='height', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='position', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='decay_a', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='decay_b', 
            data=df,jitter='0.25',kind='violin')

# %%
sns.catplot(x='beam_state', y='decay_c', 
            data=df,jitter='0.25',kind='violin')

# %%
#A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot
#points and provides some indication of the uncertainty around that estimate using error bars.

# %%
sns.pointplot(x='beam_state', y='height', 
            data=df,jitter='0.25')

# %%
sns.pointplot(x='beam_state', y='position', 
            data=df, jitter='0.25')

# %%
sns.pointplot(x='beam_state', y='decay_a', 
            data=df, jitter='0.25')

# %%
sns.pointplot(x='beam_state', y='decay_b', 
            data=df, jitter='0.25')

# %%
sns.pointplot(x='beam_state', y='decay_c', 
            data=df, jitter='0.25')

# %%
# Analyzing the distribution between the features when they are split

# %%
inj_dataframe = df.loc[df['beam_state'] == 'I']
ft_dataframe = df.loc[df['beam_state'] == 'FT']

# %%
sns.kdeplot(inj_dataframe.height, shade=True);
sns.kdeplot(ft_dataframe.height, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: height')
# Out:
# Text(0.5, 1.0, 'Feature: height')

# %%
sns.kdeplot(inj_dataframe.position, shade=True);
sns.kdeplot(ft_dataframe.position, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: position')
# Out:
# Text(0.5, 1.0, 'Feature: position')

# %%
sns.kdeplot(inj_dataframe.decay_a, shade=True);
sns.kdeplot(ft_dataframe.decay_a, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: decay_a')
# Out:
# Text(0.5, 1.0, 'Feature: decay_a')

# %%
sns.kdeplot(inj_dataframe.decay_b, shade=True);
sns.kdeplot(ft_dataframe.decay_b, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: decay_b')
# Out:
# Text(0.5, 1.0, 'Feature: decay_b')

# %%
sns.kdeplot(inj_dataframe.decay_c, shade=True);
sns.kdeplot(ft_dataframe.decay_c, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: decay_c')
# Out:
# Text(0.5, 1.0, 'Feature: decay_c')

# %%
sns.kdeplot(inj_dataframe.jaw, shade=True);
sns.kdeplot(ft_dataframe.jaw, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: jaw')
# Out:
# Text(0.5, 1.0, 'Feature: jaw')

# %%
sns.kdeplot(inj_dataframe.spike, shade=True);
sns.kdeplot(ft_dataframe.spike, shade=True, color='red');
plt.legend(loc='upper left', labels=['Injection', 'Flat Top'])
plt.title('Feature: spike')
# Out:
# Text(0.5, 1.0, 'Feature: spike')
