# %%
import math
import numpy as np
theta = 2e-06
LU = 3.07
centre = -0.2649999999999999
sigma_x = 1.785544904854558
sigma_y = 0.8120118412303785
#
beam_size = math.sqrt((math.pow(sigma_x,2) * math.pow(math.cos(theta),2)) + (math.pow(sigma_y,2) * math.pow(math.sin(theta),2)))
pos_sigma_a = np.abs(LU)/beam_size

# %%
print(pos_sigma_a)
# Out:
# 1.719363087233551
