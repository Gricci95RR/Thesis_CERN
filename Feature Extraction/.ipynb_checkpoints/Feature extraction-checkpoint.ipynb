# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import iglob
import math

# %%
# import of i_col_info
i_col_info = pd.read_csv(r'/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/col_info/2018/i_col_info.csv')
print(i_col_info)
# Out:
#        collimator   angle  centre   sigma_x   sigma_y
# 0   TCDQA.A4L6.B2  0.0000   0.005  2.085586  1.182871
# 1   TCDQA.A4R6.B1  0.0000   0.450  1.884613  1.054809
# 2      TCL.4L1.B2  0.0000   0.000  0.769776  1.112680
# 3      TCL.4L5.B2  0.0000   0.000  0.769776  1.112680
# 4      TCL.4R1.B1  0.0000   0.000  0.769776  1.112681
# ..            ...     ...     ...       ...       ...
# 91   TCTPV.4R2.B2  1.5708  -0.793  0.581177  0.570235
# 92   TCTPV.4R5.B2  1.5708   0.625  1.057516  0.747119
# 93   TCTPV.4R8.B2  1.5708   1.440  0.551713  0.538141
# 94        TDI.4L2  1.5710     NaN       NaN       NaN
# 95        TDI.4R8  1.5708     NaN       NaN       NaN
#
# [96 rows x 5 columns]

# %%
filenames = iglob('/Users/gianmarcoricci/Google Drive/UNI/Thesis CERN/Data/Auto_data/2-test_2018/*_Align')

# %%
pos_sigma = []
spike_height = []
variance = []
for i in filenames:
    df = pd.read_csv(i, sep="=", header = None, nrows=9)
    df2 = pd.read_csv(i, skiprows=10, header = None)
    df3 = pd.concat([df, df2])
    df4 = pd.read_csv(i, skiprows=11, header = None) # dataframe with only BLM values
    theta = df3.iat[2,1]
    LU = df3.iat[5,1] 
    name = df3.iat[9,0]
    name2 = name[17:]
    for j in i_col_info.index:
        if i_col_info.iat[j,0] == name2:
            # pos_sigma
            centre = i_col_info.iat[j,2]
            sigma_x = i_col_info.iat[j,3]
            sigma_y = i_col_info.iat[j,4]
            beam_size = math.sqrt((math.pow(sigma_x,2) * math.pow(math.cos(theta),2)) + (math.pow(sigma_y,2) * math.pow(math.sin(theta),2)))
            pos_sigma_a = np.abs(LU)/beam_size
            pos_sigma.append(pos_sigma_a)
           
            # spike_height
            #Search data for max value
            #flattop - [30:75], injection - [80:125]
            max_val = df4.iloc[80:125,0].max()
            max_index = df4[df4[0] == max_val].index[0]
            #Steady state average before spike
            spike_start = max_index - 10 	#point when collimator moves in
            df_steady = df4.iloc[0:spike_start,0]
            avg = df_steady.sum() / len(df_steady)
            s_h = max_val - avg
            spike_height.append(s_h)
            v = df4[0].var()
            variance.append(v)
            
            print(i_col_info.iat[j,0])
            print("Position sigma:", pos_sigma_a)
            print("Maximum value:", max_val)
            print("Spike height:", s_h)
            print("Variance:", v)
            print("\n")
# Out:
# TCP.C6R7.B2
# Position sigma: 5.929757138929084
# Maximum value: 1.1041e-05
# Spike height: 8.298467289719625e-06
# Variance: 5.2046744966435305e-12
#
#
# TCLA.7R3.B1
# Position sigma: 2.483055806344275
# Maximum value: 0.00026136400000000004
# Spike height: 0.00025804266292134834
# Variance: 9.225858466898102e-10
#
#
# TCTPH.4R5.B2
# Position sigma: 5.1540664442552915
# Maximum value: 0.000153488
# Spike height: 0.00013997333333333332
# Variance: 2.3094098898566372e-10
#
#
# TCLA.B6L7.B2
# Position sigma: 8.834015885550293
# Maximum value: 1.3755999999999998e-05
# Spike height: 1.1339365853658535e-05
# Variance: 4.245856479714416e-10
#
#
# TCP.D6L7.B1
# Position sigma: 3.8170228918290015
# Maximum value: 5.249e-06
# Spike height: 3.410351063829787e-06
# Variance: 1.6887151091136657e-12
#
#
# TCSP.A4L6.B2
# Position sigma: 2.414187059881946
# Maximum value: 1.7195e-05
# Spike height: 1.199168085106383e-05
# Variance: 1.2230832315394245e-11
#
#
# TCLA.A7R7.B1
# Position sigma: 2.3297063930982658
# Maximum value: 0.00306379
# Spike height: 0.0030483597499999997
# Variance: 7.1227100701811e-08
#
#
# TCP.C6L7.B1
# Position sigma: 4.656028133222638
# Maximum value: 0.000425531
# Spike height: 0.00042213658888888886
# Variance: 1.7563734286271482e-09
#
#
# TCLA.A7L7.B2
# Position sigma: 3.111336362482309
# Maximum value: 0.000751512
# Spike height: 0.0007237329801980198
# Variance: 6.078069392726478e-09
#
#
# TCLA.D6L7.B2
# Position sigma: 3.19834812695142
# Maximum value: 3.62e-06
# Spike height: -7.887423076923078e-06
# Variance: 1.0935523275512016e-10
#
#
# TCSG.5R3.B2
# Position sigma: 4.174199031835154
# Maximum value: 1.5204e-05
# Spike height: 1.418169512195122e-05
# Variance: 3.885764304403232e-11
#
#
# TCP.C6L7.B1
# Position sigma: 5.137850714859662
# Maximum value: 4.9232e-05
# Spike height: 4.749170212765957e-05
# Variance: 2.2272645699624512e-11
#
#
# TCP.C6L7.B1
# Position sigma: 3.5635789401433606
# Maximum value: 0.00126501
# Spike height: 0.0012504140786516855
# Variance: 1.5678566337569117e-08
#
#
# TCLA.D6R7.B1
# Position sigma: 5.286044620345745
# Maximum value: 0.020061900000000004
# Spike height: 0.020028030375000005
# Variance: 2.2989928447435715e-06
#
#
# TCLA.7R3.B1
# Position sigma: 2.597219292351457
# Maximum value: 9.104299999999999e-05
# Spike height: 8.952640697674417e-05
# Variance: 1.3301959531949024e-10
#
#
# TCP.B6L7.B1
# Position sigma: 2.064460155631239
# Maximum value: 0.000400915
# Spike height: 0.00039230236559139784
# Variance: 1.5506143200421836e-09
#
#
# TCP.D6L7.B1
# Position sigma: 2.748999454969739
# Maximum value: 2.6606999999999998e-05
# Spike height: 2.4602767441860464e-05
# Variance: 7.323482648537943e-12
#
#
# TCSG.B5L7.B1
# Position sigma: 1.9498661675247935
# Maximum value: 7.5296e-05
# Spike height: 6.968705681818182e-05
# Variance: 1.0651089309349746e-10
#
#
# TCSG.D4L7.B1
# Position sigma: 1.260119526504086
# Maximum value: 5.3576000000000003e-05
# Spike height: 5.1258575e-05
# Variance: 2.395576324732618e-11
#
#
# TCLA.7R3.B1
# Position sigma: 2.597219292219853
# Maximum value: 0.00026100200000000003
# Spike height: 0.00025719225882352945
# Variance: 5.288874683575781e-10
#
#
# TCP.C6L7.B1
# Position sigma: 4.326862208701081
# Maximum value: 0.000415395
# Spike height: 0.00041244337974683545
# Variance: 1.2822086892197913e-09
#
#
# TCP.C6L7.B1
# Position sigma: 2.7144262387257614
# Maximum value: 0.00023530000000000003
# Spike height: 0.00019154768627450985
# Variance: 9.426875206467178e-10
#
#
# TCLA.B6R7.B1
# Position sigma: 2.9484369965365698
# Maximum value: 9.593e-06
# Spike height: 6.571864197530864e-06
# Variance: 2.4850452302594157e-12
#
#
# TCP.B6L7.B1
# Position sigma: 2.858860497905795
# Maximum value: 0.000135026
# Spike height: 0.00012496905747126438
# Variance: 2.0330539040490944e-10
#
#
# TCLA.B5R3.B1
# Position sigma: 5.917913432835154
# Maximum value: 9.05e-07
# Spike height: 2.9966666666666666e-07
# Variance: 4.0783789054499936e-14
#
#
# TCSG.A4L7.B1
# Position sigma: 3.7986072381093825
# Maximum value: 1.7557e-05
# Spike height: 1.572887804878049e-05
# Variance: 2.735260148822392e-12
#
#
# TCLA.A6R7.B1
# Position sigma: 1.489853856845898
# Maximum value: 2.172e-05
# Spike height: 1.6658830188679244e-05
# Variance: 1.6219546537717578e-11
#
#
# TCTPH.4R1.B2
# Position sigma: 1.5037430773337723
# Maximum value: 1.1222e-05
# Spike height: 1.0007125e-05
# Variance: 3.8497808073728525e-12
#
#
# TCSP.A4R6.B1
# Position sigma: 4.239592287275775
# Maximum value: 5.3938000000000004e-05
# Spike height: 5.05519756097561e-05
# Variance: 8.894435934736595e-11
#
#
# TCSG.A6L7.B1
# Position sigma: 3.392203305819636
# Maximum value: 0.00030589
# Spike height: 0.000294287275862069
# Variance: 9.234955050996703e-10
#
#
# TCSG.A4L7.B1
# Position sigma: 4.155923036542964
# Maximum value: 5.792000000000001e-06
# Spike height: 4.162912500000001e-06
# Variance: 7.032032937763121e-13
#
#
# TCP.B6L7.B1
# Position sigma: 3.0550087310382685
# Maximum value: 8.6156e-05
# Spike height: 6.847527848101266e-05
# Variance: 1.1158554180074533e-10
#
#
# TCLA.6R3.B1
# Position sigma: 3.9304058585159045
# Maximum value: 0.000548792
# Spike height: 0.0005384688295454545
# Variance: 4.1025352668379805e-09
#
#
# TCP.C6R7.B2
# Position sigma: 2.2707678183050004
# Maximum value: 0.000158737
# Spike height: 0.00015466651111111112
# Variance: 7.164789212921834e-10
#
#
# TCSG.E5R7.B1
# Position sigma: 2.2476732636043772
# Maximum value: 3.9277e-05
# Spike height: 3.661817073170732e-05
# Variance: 1.7199714020025017e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.9338701864056587
# Maximum value: 0.000497569
# Spike height: 0.0004949740108695653
# Variance: 1.8753821078564966e-09
#
#
# TCP.C6L7.B1
# Position sigma: 4.479518868426718
# Maximum value: 3.4751999999999995e-05
# Spike height: 3.216474468085106e-05
# Variance: 1.5482532693366693e-11
#
#
# TCSG.D4L7.B1
# Position sigma: 1.243317932817365
# Maximum value: 4.0544000000000003e-05
# Spike height: 3.776806930693069e-05
# Variance: 1.8540462475452278e-11
#
#
# TCP.6L3.B1
# Position sigma: 4.011415662622762
# Maximum value: 6.6970000000000004e-06
# Spike height: 5.034137931034483e-06
# Variance: 4.860899318181817e-13
#
#
# TCP.C6R7.B2
# Position sigma: 2.2516857389913
# Maximum value: 0.00023457599999999998
# Spike height: 0.0002215865882352941
# Variance: 1.3033133213836608e-09
#
#
# TCTPH.4R8.B2
# Position sigma: 0.3046940108683311
# Maximum value: 9.55e-07
# Spike height: 4.478010752688171e-07
# Variance: 3.241189563659114e-14
#
#
# TCSG.A5L7.B1
# Position sigma: 1.9240407890969302
# Maximum value: 0.000179552
# Spike height: 0.0001680399358974359
# Variance: 4.4944323124462405e-10
#
#
# TCTPV.4L5.B1
# Position sigma: 3.050707536331782
# Maximum value: 1.7014e-05
# Spike height: 1.579120238095238e-05
# Variance: 2.4648796287120256e-12
#
#
# TCP.D6L7.B1
# Position sigma: 3.6219925250932126
# Maximum value: 5.611e-06
# Spike height: 3.8508484848484845e-06
# Variance: 1.3903626465752631e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.757360923158489
# Maximum value: 0.000264079
# Spike height: 0.00024771298
# Variance: 6.965305251149164e-10
#
#
# TCTPH.4R8.B2
# Position sigma: 1.0952514444723145
# Maximum value: 1.498e-06
# Spike height: 3.4066666666666614e-08
# Variance: 1.4674946049322955e-12
#
#
# TCSG.D4L7.B1
# Position sigma: 1.243317932817365
# Maximum value: 4.3258999999999994e-05
# Spike height: 4.070605813953488e-05
# Variance: 1.9914933475338473e-11
#
#
# TCSG.5L3.B1
# Position sigma: 4.681099058982642
# Maximum value: 9.412e-06
# Spike height: 7.516534090909091e-06
# Variance: 2.31856494626806e-12
#
#
# TCSG.B5L3.B2
# Position sigma: 5.108581073765921
# Maximum value: 2.353e-06
# Spike height: 1.0423090909090911e-06
# Variance: 1.7320401100807816e-13
#
#
# TCP.C6R7.B2
# Position sigma: 3.348905481067922
# Maximum value: 0.000353674
# Spike height: 0.000347603974025974
# Variance: 1.0252392346442994e-09
#
#
# TCSG.B4L7.B1
# Position sigma: 3.4768177697768086
# Maximum value: 1.9367e-05
# Spike height: 1.272767088607595e-05
# Variance: 1.2629450366224841e-11
#
#
# TCP.B6L7.B1
# Position sigma: 3.0648161426948923
# Maximum value: 5.7196000000000006e-05
# Spike height: 4.159542696629214e-05
# Variance: 6.0975571630561e-11
#
#
# TCSG.D5R7.B1
# Position sigma: 2.5732994506848734
# Maximum value: 0.00017973299999999998
# Spike height: 0.00017563598780487804
# Variance: 4.998132792468718e-10
#
#
# TCSG.B4L7.B1
# Position sigma: 4.922623179037222
# Maximum value: 3.9458e-05
# Spike height: 3.197146078431373e-05
# Variance: 6.9063517511065e-11
#
#
# TCP.C6R7.B2
# Position sigma: 2.661950511131716
# Maximum value: 0.000129777
# Spike height: 0.00010955540506329114
# Variance: 4.18276064704375e-10
#
#
# TCP.C6L7.B1
# Position sigma: 2.933870187726438
# Maximum value: 0.000778481
# Spike height: 0.0007722330632911392
# Variance: 6.545587231847874e-09
#
#
# TCSG.4R3.B1
# Position sigma: 3.052518284397376
# Maximum value: 1.7014e-05
# Spike height: 1.6198020408163264e-05
# Variance: 2.4837186629878216e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.4902117679735833
# Maximum value: 0.00037611800000000005
# Spike height: 0.00036755443750000007
# Variance: 1.3063188272280124e-09
#
#
# TCP.D6L7.B1
# Position sigma: 3.408387837697762
# Maximum value: 4.706e-06
# Spike height: 3.866807692307693e-06
# Variance: 4.704530518830354e-13
#
#
# TCSG.B5R7.B1
# Position sigma: 2.7495221600065216
# Maximum value: 0.000141542
# Spike height: 0.00013640046875
# Variance: 2.3427066984531514e-09
#
#
# TCP.B6L7.B1
# Position sigma: 2.020326802044092
# Maximum value: 0.0006193819999999999
# Spike height: 0.0005986110897435897
# Variance: 5.092219774566049e-09
#
#
# TCP.C6R7.B2
# Position sigma: 2.5665400980264135
# Maximum value: 0.000269147
# Spike height: 0.000258853068627451
# Variance: 1.5152964973926502e-09
# TCSG.A5L3.B2
# Position sigma: 5.863693774428307
# Maximum value: 1.3213e-05
# Spike height: 1.1445540229885057e-05
# Variance: 2.9556295331664575e-12
#
#
# TCP.D6L7.B1
# Position sigma: 2.396087362753972
# Maximum value: 5.5205e-05
# Spike height: 5.393797619047619e-05
# Variance: 2.6332335373990177e-11
#
#
# TCTPH.4L5.B1
# Position sigma: 1.2149090434091703
# Maximum value: 7.240000000000001e-07
# Spike height: 5.06952380952381e-07
# Variance: 3.4701847690294907e-12
#
#
# TCTPV.4L8.B1
# Position sigma: 1.3472953886277315
# Maximum value: 0.00039458
# Spike height: 0.0003859225584415584
# Variance: 1.1159685523004606e-09
#
#
# TCSG.B5R3.B1
# Position sigma: 5.403467173381877
# Maximum value: 1.3937e-05
# Spike height: 1.24684e-05
# Variance: 2.9566036856297687e-12
#
#
# TCSG.4L3.B2
# Position sigma: 2.6752295151826404
# Maximum value: 2.9865e-05
# Spike height: 2.7343066666666666e-05
# Variance: 8.675428892024126e-12
#
#
# TCLA.B6L7.B2
# Position sigma: 9.157575021599365
# Maximum value: 1.2127000000000001e-05
# Spike height: 9.629200000000001e-06
# Variance: 6.309801584793496e-12
#
#
# TCSG.6L7.B2
# Position sigma: 2.938718876121122
# Maximum value: 0.000116021
# Spike height: 0.00011079626250000001
# Variance: 2.032024763661392e-10
#
#
# TCTPH.4R5.B2
# Position sigma: 6.175887703516222
# Maximum value: 4.343999999999999e-06
# Spike height: 2.782944444444444e-06
# Variance: 1.854661371942202e-12
#
#
# TCLA.B6L7.B2
# Position sigma: 8.83401589115718
# Maximum value: 0.00029738299999999997
# Spike height: 0.00029168489887640447
# Variance: 1.3797128844337247e-09
#
#
# TCTPH.4R8.B2
# Position sigma: 1.4411203216410136
# Maximum value: 0.00019729
# Spike height: 0.00019161394936708862
# Variance: 7.242367684444193e-10
#
#
# TCTPH.4L2.B1
# Position sigma: 4.226518964400563
# Maximum value: 0.00364027
# Spike height: 0.003627293059405941
# Variance: 8.320730117225634e-08
#
#
# TCP.C6L7.B1
# Position sigma: 4.002466811469705
# Maximum value: 0.00045250000000000005
# Spike height: 0.0004496018452380953
# Variance: 2.311148711894954e-09
#
#
# TCP.C6R7.B2
# Position sigma: 5.5576565300501874
# Maximum value: 1.1765e-05
# Spike height: 9.070243902439023e-06
# Variance: 4.8756215541017135e-12
#
#
# TCTPH.4L8.B1
# Position sigma: 5.052274676535753
# Maximum value: 0.000192222
# Spike height: 0.00016376736633663366
# Variance: 9.241473172325349e-10
#
#
# TCTPV.4L1.B1
# Position sigma: 2.1357261222489448
# Maximum value: 1.4842000000000001e-05
# Spike height: 1.0762644859813085e-05
# Variance: 1.1532481604590973e-11
#
#
# TCTPH.4L5.B1
# Position sigma: 0.7765889180183527
# Maximum value: 0.000221363
# Spike height: 0.00021727549397590362
# Variance: 4.091306550075088e-10
#
#
# TCSG.4R3.B1
# Position sigma: 2.5952114441136893
# Maximum value: 0.00155805
# Spike height: 0.0015471180361445783
# Variance: 2.875515459949447e-08
#
#
# TCLA.A7L7.B2
# Position sigma: 3.460020615032047
# Maximum value: 7.964e-06
# Spike height: 6.879831460674158e-06
# Variance: 2.1890291200676975e-11
#
#
# TCLA.D6R7.B1
# Position sigma: 5.384389492404645
# Maximum value: 0.0113411
# Spike height: 0.011292476806818181
# Variance: 7.435570041160961e-07
#
#
# TCSG.B5R7.B1
# Position sigma: 2.7495221554032026
# Maximum value: 0.000276206
# Spike height: 0.00027063036781609193
# Variance: 1.1854115778765502e-09
#
#
# TCP.C6L7.B1
# Position sigma: 3.1246910121707416
# Maximum value: 9.086200000000001e-05
# Spike height: 6.722173563218391e-05
# Variance: 2.828001908055526e-10
#
#
# TCP.B6L7.B1
# Position sigma: 2.966742026643829
# Maximum value: 0.00017846599999999998
# Spike height: 0.00016367969230769228
# Variance: 2.8682201451245864e-10
#
#
# TCLA.C6R7.B1
# Position sigma: 7.226062954976988
# Maximum value: 2.6788000000000002e-05
# Spike height: 2.4236138297872343e-05
# Variance: 1.4378011323472543e-11
#
#
# TCTPV.4L2.B1
# Position sigma: 6.450648105243012
# Maximum value: 7.240000000000001e-07
# Spike height: 4.057014925373136e-07
# Variance: 3.6519724741153745e-14
#
#
# TCP.C6L7.B1
# Position sigma: 2.59993374148817
# Maximum value: 9.936899999999999e-05
# Spike height: 5.1408936363636354e-05
# Variance: 1.2925502379304535e-09
#
#
# TCP.C6R7.B2
# Position sigma: 2.852771334953965
# Maximum value: 0.000176656
# Spike height: 0.00016926620689655173
# Variance: 5.967731384699056e-10
#
#
# TCP.B6L7.B1
# Position sigma: 2.5352159142155233
# Maximum value: 0.00046698
# Spike height: 0.0004593594358974359
# Variance: 1.933092352894755e-09
#
#
# TCP.C6R7.B2
# Position sigma: 3.84026910445528
# Maximum value: 1.8824e-05
# Spike height: 1.582972641509434e-05
# Variance: 1.081840246694731e-11
#
#
# TCSG.5R3.B2
# Position sigma: 4.776170809138395
# Maximum value: 2.1719999999999997e-06
# Spike height: 9.587922077922077e-07
# Variance: 2.55074769825919e-13
#
#
# TCSG.B5L3.B2
# Position sigma: 3.9637038207877233
# Maximum value: 1.1222e-05
# Spike height: 7.93453488372093e-06
# Variance: 1.3148039709580155e-12
#
#
# TCP.D6L7.B1
# Position sigma: 3.8170228918290015
# Maximum value: 7.783e-06
# Spike height: 6.333827956989247e-06
# Variance: 1.8990168820116065e-12
#
#
# TCP.C6L7.B1
# Position sigma: 3.6399072384111624
# Maximum value: 0.0006921439999999999
# Spike height: 0.0006846175824175824
# Variance: 3.5748909433758104e-09
#
#
# TCSG.D5R7.B1
# Position sigma: 2.5183814752873013
# Maximum value: 0.000203263
# Spike height: 0.0001972696375
# Variance: 9.58951491358857e-10
#
#
# TCTPV.4L5.B1
# Position sigma: 3.457468541157836
# Maximum value: 4.525e-06
# Spike height: 3.975426966292135e-06
# Variance: 3.31254052565707e-13
#
#
# TCSG.5L3.B1
# Position sigma: 4.586051361953917
# Maximum value: 3.6743000000000004e-05
# Spike height: 3.279539e-05
# Variance: 1.6333290277022396e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.685803112766678
# Maximum value: 0.000225707
# Spike height: 0.00013992808333333334
# Variance: 2.1404660163194923e-09
#
#
# TCP.B6L7.B1
# Position sigma: 5.158698529816384
# Maximum value: 1.0498e-05
# Spike height: 8.782971428571428e-06
# Variance: 5.581416675702585e-12
#
#
# TCSP.A4L6.B2
# Position sigma: 2.380623386997792
# Maximum value: 4.8508000000000004e-05
# Spike height: 3.934661538461539e-05
# Variance: 7.0410478705541e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.5808516604341545
# Maximum value: 0.00071314
# Spike height: 0.0006873726907216495
# Variance: 6.252627648625181e-09
#
#
# TCSG.A5L3.B2
# Position sigma: 6.098241526427363
# Maximum value: 3.801e-06
# Spike height: 2.6266774193548387e-06
# Variance: 9.308733826373879e-13
#
#
# TCLA.D6L7.B2
# Position sigma: 2.1087305285912166
# Maximum value: 5.429999999999999e-05
# Spike height: 4.149076923076922e-05
# Variance: 7.805372456192399e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.6667210341019842
# Maximum value: 0.00165054
# Spike height: 0.0016017469770114943
# Variance: 2.0462904565881326e-08
#
#
# TCP.C6R7.B2
# Position sigma: 2.805066129441508
# Maximum value: 0.00025702
# Spike height: 0.0002458443536585366
# Variance: 1.2471654841821314e-09
#
#
# TCLA.B5L3.B2
# Position sigma: 3.3653842860469125
# Maximum value: 1.4118e-05
# Spike height: 7.4115974025974005e-06
# Variance: 4.437492173626116e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.8527713347613246
# Maximum value: 4.0906e-05
# Spike height: 3.292339252336448e-05
# Variance: 5.069514727918422e-11
#
#
# TCSG.B5L7.B1
# Position sigma: 1.9182253371850584
# Maximum value: 0.000577752
# Spike height: 0.0005649749569892473
# Variance: 5.540387447758336e-09
#
#
# TCLA.A5R3.B1
# Position sigma: 5.08879899419707
# Maximum value: 2.9684000000000002e-05
# Spike height: 2.710786363636364e-05
# Variance: 1.3639849753896915e-11
#
#
# TCTPV.4L5.B1
# Position sigma: 3.4122728739711046
# Maximum value: 5.972999999999999e-06
# Spike height: 5.109385416666666e-06
# Variance: 7.559592111446122e-13
#
#
# TCP.C6R7.B2
# Position sigma: 2.8909355007509414
# Maximum value: 0.00019729
# Spike height: 0.00018406280392156864
# Variance: 5.854003077245421e-10
#
#
# TCP.B6L7.B1
# Position sigma: 2.7215567347130643
# Maximum value: 0.000107333
# Spike height: 9.230999999999999e-05
# Variance: 1.3876480488667654e-10
#
#
# TCLA.C6R7.B1
# Position sigma: 7.200506587320128
# Maximum value: 4.1992e-05
# Spike height: 3.85168e-05
# Variance: 2.0236390931704408e-11
#
#
# TCLA.6L3.B2
# Position sigma: 3.0455677389395968
# Maximum value: 1.4660999999999999e-05
# Spike height: 1.0246173913043476e-05
# Variance: 4.4771937791557594e-12
#
#
# TCLA.7R3.B1
# Position sigma: 7.877280491215663
# Maximum value: 2.041e-06
# Spike height: 1.6759113924050632e-06
# Variance: 2.1016380202525872e-13
#
#
# TCP.C6L7.B1
# Position sigma: 2.599933742951228
# Maximum value: 0.000879117
# Spike height: 0.0008569936847826087
# Variance: 1.990549833225267e-08
#
#
# TCSG.A5L3.B2
# Position sigma: 5.980967650919144
# Maximum value: 8.687999999999999e-06
# Spike height: 6.915987654320986e-06
# Variance: 1.6273623248094215e-12
#
#
# TCTPV.4L1.B1
# Position sigma: 2.4838961858915103
# Maximum value: 7.421000000000001e-06
# Spike height: 6.70031182795699e-06
# Variance: 7.674995941233357e-13
#
#
# TCTPV.4L8.B1
# Position sigma: 1.9460933390534794
# Maximum value: 5.792000000000001e-06
# Spike height: 5.137028571428572e-06
# Variance: 1.3570350154454431e-12
#
#
# TCTPV.4L2.B1
# Position sigma: 2.1444973754156345
# Maximum value: 2.896e-05
# Spike height: 2.6762311111111112e-05
# Variance: 1.0723815309705307e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.5808516822189533
# Maximum value: 0.00043204699999999996
# Spike height: 0.00038826788505747124
# Variance: 3.0667293469353728e-09
#
#
# TCSG.A4L7.B1
# Position sigma: 2.633077133690044
# Maximum value: 2.2444e-05
# Spike height: 1.912845054945055e-05
# Variance: 1.7479982859568792e-11
#
#
# TCSG.A5R3.B1
# Position sigma: 4.642093493138423
# Maximum value: 3.1494e-05
# Spike height: 2.9375869047619047e-05
# Variance: 2.5035751932984446e-11
#
#
# TCSG.D5R7.B1
# Position sigma: 2.5183814749941082
# Maximum value: 0.000317474
# Spike height: 0.0003135214175824176
# Variance: 1.1445923200992996e-09
#
#
# TCLA.7R3.B1
# Position sigma: 8.904751859635098
# Maximum value: 2.9460000000000003e-06
# Spike height: 2.497630434782609e-06
# Variance: 2.7592231593469076e-13
#
#
# TCP.D6L7.B1
# Position sigma: 3.1019115471311105
# Maximum value: 9.593e-06
# Spike height: 8.683869565217391e-06
# Variance: 1.172972898168165e-12
# TCP.C6L7.B1
# Position sigma: 4.889783644009431
# Maximum value: 0.000218648
# Spike height: 0.00021673040594059407
# Variance: 3.5521987871248146e-10
#
#
# TCSP.A4R6.B1
# Position sigma: 4.239592287275775
# Maximum value: 8.5794e-05
# Spike height: 8.01872588235294e-05
# Variance: 2.0331901162282405e-10
#
#
# TCP.C6L7.B1
# Position sigma: 4.8325373947990045
# Maximum value: 0.000253943
# Spike height: 0.0002521239090909091
# Variance: 6.269905568168171e-10
#
#
# TCTPH.4R1.B2
# Position sigma: 3.3676641372443794
# Maximum value: 1.0859999999999999e-06
# Spike height: 7.847499999999999e-07
# Variance: 1.1615213297872333e-13
#
#
# TCP.B6L7.B1
# Position sigma: 2.1233046271003206
# Maximum value: 0.000705357
# Spike height: 0.0006868648333333334
# Variance: 8.357471660308226e-09
#
#
# TCLA.6L3.B2
# Position sigma: 3.0147004983257717
# Maximum value: 3.3666e-05
# Spike height: 2.6905117647058823e-05
# Variance: 1.5922483402548635e-11
#
#
# TCP.D6L7.B1
# Position sigma: 2.9440298216783294
# Maximum value: 1.5928e-05
# Spike height: 1.4820326315789474e-05
# Variance: 2.1875121363067482e-12
#
#
# TCSG.B5R3.B1
# Position sigma: 5.854478879667362
# Maximum value: 3.4389999999999996e-06
# Spike height: 2.4123950617283947e-06
# Variance: 1.9051153203720557e-12
#
#
# TCP.B6L7.B1
# Position sigma: 2.7215567347130643
# Maximum value: 0.000156384
# Spike height: 0.00014312628235294117
# Variance: 3.429929090988738e-10
#
#
# TCSG.5R3.B2
# Position sigma: 3.9841026809187765
# Maximum value: 3.258e-05
# Spike height: 2.8705738095238097e-05
# Variance: 2.934856667709635e-11
#
#
# TCSP.A4R6.B1
# Position sigma: 4.584490282523588
# Maximum value: 1.0859999999999999e-06
# Spike height: 2.398095238095236e-07
# Variance: 4.7388841634713924e-12
#
#
# TCTPH.4L5.B1
# Position sigma: 0.6813019344214326
# Maximum value: 0.000317655
# Spike height: 0.000315670686746988
# Variance: 1.2502930162096666e-09
#
#
# TCSG.B4L7.B1
# Position sigma: 4.6767379053590385
# Maximum value: 5.6653e-05
# Spike height: 4.988629213483146e-05
# Variance: 6.235379695491536e-11
#
#
# TCTPV.4L2.B1
# Position sigma: 2.0930294384056594
# Maximum value: 1.5928e-05
# Spike height: 1.4147679487179488e-05
# Variance: 7.074678500625786e-12
#
#
# TCLA.6L3.B2
# Position sigma: 3.0147004983257717
# Maximum value: 1.5928e-05
# Spike height: 1.0494229166666666e-05
# Variance: 6.580747992803501e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.938640706041766
# Maximum value: 6.2264e-05
# Spike height: 5.502579207920792e-05
# Variance: 9.900756175591647e-11
#
#
# TCP.C6L7.B1
# Position sigma: 4.889783644009431
# Maximum value: 0.000240187
# Spike height: 0.00023771859782608696
# Variance: 6.758435857845035e-10
#
#
# TCP.B6L7.B1
# Position sigma: 4.776209475324294
# Maximum value: 1.3575e-05
# Spike height: 1.1812987654320988e-05
# Variance: 6.405110822505406e-12
#
#
# TCTPV.4L5.B1
# Position sigma: 3.1049423369776807
# Maximum value: 1.4660999999999999e-05
# Spike height: 1.3659104651162789e-05
# Variance: 2.407816447604958e-12
#
#
# TCTPH.4R8.B2
# Position sigma: 1.5234700543062143
# Maximum value: 0.000140275
# Spike height: 0.0001356189898989899
# Variance: 2.486897298446641e-10
#
#
# TCSG.4R3.B1
# Position sigma: 3.3269019504106234
# Maximum value: 1.4480000000000002e-06
# Spike height: 8.251578947368422e-07
# Variance: 1.7724084415462542e-12
#
#
# TCSG.A5R3.B1
# Position sigma: 5.61937633524787
# Maximum value: 9.05e-07
# Spike height: 2.064821428571429e-07
# Variance: 5.086278869040856e-13
#
#
# TCLA.6L3.B2
# Position sigma: 3.0867240597360777
# Maximum value: 1.5566e-05
# Spike height: 1.1398690476190477e-05
# Variance: 4.409770754010699e-12
#
#
# TCP.6L3.B1
# Position sigma: 3.9297583463352757
# Maximum value: 8.326e-06
# Spike height: 6.6065e-06
# Variance: 6.283223579474347e-13
#
#
# TCLA.B6L7.B2
# Position sigma: 8.484912614998665
# Maximum value: 7.0409e-05
# Spike height: 4.956495061728395e-05
# Variance: 9.749453957045734e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.723967302305032
# Maximum value: 0.00049051
# Spike height: 0.00046109965476190477
# Variance: 4.028449487761976e-09
#
#
# TCSG.4L3.B2
# Position sigma: 2.8581511926415684
# Maximum value: 3.62e-06
# Spike height: 3.05045e-06
# Variance: 6.335641647513938e-13
#
#
# TCSG.6L7.B2
# Position sigma: 3.974445698191002
# Maximum value: 4.887e-06
# Spike height: -6.004210526315788e-06
# Variance: 5.148198881988854e-11
#
#
# TCLA.7L3.B2
# Position sigma: 4.207232034210574
# Maximum value: 1.4118e-05
# Spike height: 1.3004682352941175e-05
# Variance: 1.6550498970019368e-12
#
#
# TCP.D6L7.B1
# Position sigma: 2.396087362777678
# Maximum value: 2.4616e-05
# Spike height: 2.257190588235294e-05
# Variance: 8.446103971669124e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.5665401007994055
# Maximum value: 0.000987898
# Spike height: 0.0009671201282051283
# Variance: 9.291936060925559e-09
#
#
# TCSG.4L3.B2
# Position sigma: 2.583768676401995
# Maximum value: 5.4843e-05
# Spike height: 5.070428048780488e-05
# Variance: 3.250397674101146e-11
#
#
# TCTPH.4R8.B2
# Position sigma: 1.4411203216410136
# Maximum value: 0.000230775
# Spike height: 0.00022012754022988508
# Variance: 8.54418377197179e-10
#
#
# TCSG.B5L7.B1
# Position sigma: 1.8707640903037013
# Maximum value: 0.000428789
# Spike height: 0.0004064901584158416
# Variance: 3.585740910201274e-09
#
#
# TCLA.A7R7.B1
# Position sigma: 4.144263202307752
# Maximum value: 1.0859999999999999e-06
# Spike height: 6.084999999999999e-07
# Variance: 1.3157825699738296e-13
#
#
# TCTPH.4R2.B2
# Position sigma: 4.215226136082987
# Maximum value: 0.00018462
# Spike height: 0.00017859345783132532
# Variance: 4.4161397826450625e-10
#
#
# TCLA.A7L7.B2
# Position sigma: 3.1649800945699007
# Maximum value: 8.0726e-05
# Spike height: 6.198061616161617e-05
# Variance: 1.3168361668380927e-10
#
#
# TCLA.A7R7.B1
# Position sigma: 2.3297063980976813
# Maximum value: 0.00365204
# Spike height: 0.0036299399
# Variance: 1.6662748588612864e-07
#
#
# TCSG.6L7.B2
# Position sigma: 2.9699154671627475
# Maximum value: 7.8373e-05
# Spike height: 7.227389795918367e-05
# Variance: 5.2244297710888574e-11
#
#
# TCP.B6L7.B1
# Position sigma: 2.1821490944408275
# Maximum value: 0.000641645
# Spike height: 0.0006205797283950617
# Variance: 5.4931982185773105e-09
#
#
# TCSG.4L3.B2
# Position sigma: 2.6752295151826404
# Maximum value: 1.8824e-05
# Spike height: 1.7163218390804598e-05
# Variance: 5.790552756172488e-12
#
#
# TCSG.A5L3.B2
# Position sigma: 5.746419898939741
# Maximum value: 1.6833e-05
# Spike height: 1.4315837209302325e-05
# Variance: 6.9143592682614665e-12
#
#
# TCLA.6R3.B1
# Position sigma: 4.115608232558272
# Maximum value: 0.000658116
# Spike height: 0.0006493918000000001
# Variance: 3.74504829717556e-09
#
#
# TCTPH.4R8.B2
# Position sigma: 1.309360749399595
# Maximum value: 7.583899999999999e-05
# Spike height: 7.486765999999999e-05
# Variance: 6.813830981784047e-11
#
#
# TCP.C6R7.B2
# Position sigma: 3.158084655935847
# Maximum value: 0.00013683600000000002
# Spike height: 0.00012948016000000003
# Variance: 1.4281494268574363e-10
#
#
# TCSG.4R3.B1
# Position sigma: 2.5952121456032518
# Maximum value: 0.00129596
# Spike height: 0.0012882663544303797
# Variance: 1.6203727846560485e-08
#
#
# TCSG.B5R3.B1
# Position sigma: 5.264694340076428
# Maximum value: 2.2082e-05
# Spike height: 1.954589534883721e-05
# Variance: 7.60091673318921e-12
#
#
# TCP.C6R7.B2
# Position sigma: 3.6542188000158315
# Maximum value: 4.1087e-05
# Spike height: 3.813298717948718e-05
# Variance: 2.0624669098873583e-11
#
#
# TCLA.D6L7.B2
# Position sigma: 2.0702734374755187
# Maximum value: 7.2943e-05
# Spike height: 2.416534693877551e-05
# Variance: 6.452371606338323e-10
#
#
# TCLA.D6R7.B1
# Position sigma: 5.449952990143468
# Maximum value: 1.0679e-05
# Spike height: 9.756333333333333e-06
# Variance: 7.614429530079302e-09
#
#
# TCP.C6R7.B2
# Position sigma: 3.8784332694685
# Maximum value: 3.2037e-05
# Spike height: 2.6843059405940593e-05
# Variance: 2.8820747189071557e-11
#
#
# TCP.C6R7.B2
# Position sigma: 2.251685740815908
# Maximum value: 0.00038806400000000003
# Spike height: 0.00037273859756097564
# Variance: 2.718438697305352e-09
#
#
# TCP.C6L7.B1
# Position sigma: 3.1246910121707416
# Maximum value: 0.000285256
# Spike height: 0.000265477225
# Variance: 1.1583724138206852e-09
#
#
# TCP.D6L7.B1
# Position sigma: 2.6468406914404583
# Maximum value: 3.0589e-05
# Spike height: 2.9364000000000002e-05
# Variance: 8.453402693139157e-12
#
#
# TCLA.A7R7.B1
# Position sigma: 2.606503200883498
# Maximum value: 0.000138646
# Spike height: 0.00013038689130434784
# Variance: 2.1499653569643875e-10
#
#
# TCTPH.4L8.B1
# Position sigma: 4.978787044695621
# Maximum value: 0.00831514
# Spike height: 0.008294489545454546
# Variance: 4.299258645334167e-07
#
#
# TCP.C6R7.B2
# Position sigma: 3.735317650951429
# Maximum value: 8.7966e-05
# Spike height: 8.409878048780489e-05
# Variance: 7.848179908146552e-11
#
#
# TCLA.7L3.B2
# Position sigma: 4.207232034210574
# Maximum value: 1.0136000000000001e-05
# Spike height: 8.78779347826087e-06
# Variance: 1.53427101126408e-12
#
#
# TCLA.D6L7.B2
# Position sigma: 2.070273422697196
# Maximum value: 0.00165832
# Spike height: 0.001621887847826087
# Variance: 2.245937370448034e-08
#
#
# TCTPH.4R5.B2
# Position sigma: 5.554620376623789
# Maximum value: 7.421000000000001e-06
# Spike height: 5.537641975308642e-06
# Variance: 2.9205491540277626e-12
#
#
# TCP.B6L7.B1
# Position sigma: 3.0550087310382685
# Maximum value: 6.6789e-05
# Spike height: 5.1319964285714294e-05
# Variance: 9.314267553336563e-11
#
#
# TCP.C6R7.B2
# Position sigma: 2.3184730245719125
# Maximum value: 4.163e-05
# Spike height: 3.453118e-05
# Variance: 3.8642856599470885e-11
#
#
# TCTPH.4L1.B1
# Position sigma: 1.2650566950836926
# Maximum value: 0.000126157
# Spike height: 0.00012447765384615385
# Variance: 9.482974842675534e-11
# TCLA.A5R3.B1
# Position sigma: 5.255484125052259
# Maximum value: 1.267e-05
# Spike height: 1.1419537735849057e-05
# Variance: 4.7718586149448145e-12
#
#
# TCTPV.4L5.B1
# Position sigma: 3.050707536331782
# Maximum value: 8.326e-06
# Spike height: 7.0282941176470585e-06
# Variance: 1.0382512779610898e-12
#
#
# TCLA.A6R7.B1
# Position sigma: 2.11981320401641
# Maximum value: 4.343999999999999e-06
# Spike height: 2.5191415929203532e-06
# Variance: 2.906966000682675e-13
#
#
# TCP.C6R7.B2
# Position sigma: 4.002466805761466
# Maximum value: 1.1945999999999999e-05
# Spike height: 8.651799999999997e-06
# Variance: 6.30533813266583e-12
#
#
# TCSG.A6L7.B1
# Position sigma: 3.392203305819636
# Maximum value: 7.348600000000001e-05
# Spike height: 6.235181188118813e-05
# Variance: 1.062115450006543e-10
#
#
# TCP.B6L7.B1
# Position sigma: 2.3488751091642817
# Maximum value: 0.00143388
# Spike height: 0.0014144396835443038
# Variance: 2.122729598207383e-08
#
#
# TCSG.D5R7.B1
# Position sigma: 5.844841739868615
# Maximum value: 3.077e-06
# Spike height: -2.088424242424242e-06
# Variance: 1.784676368801912e-11
#
#
# TCTPH.4L2.B1
# Position sigma: 4.442801384894605
# Maximum value: 0.000960205
# Spike height: 0.0009553074432989691
# Variance: 9.238169457923312e-09
#
#
# TCSG.A5L7.B1
# Position sigma: 1.9033521782769944
# Maximum value: 0.000282541
# Spike height: 0.0002733162413793103
# Variance: 1.290110716661166e-09
#
#
# TCLA.B5L3.B2
# Position sigma: 3.450944903495776
# Maximum value: 1.8100000000000003e-05
# Spike height: 1.4219273809523812e-05
# Variance: 6.545438314484011e-12
#
#
# TCP.C6L7.B1
# Position sigma: 3.4872505799951328
# Maximum value: 0.000895407
# Spike height: 0.0008808310699999999
# Variance: 6.5406268645718525e-09
#
#
# TCP.C6R7.B2
# Position sigma: 2.8909354997748538
# Maximum value: 5.7739e-05
# Spike height: 5.051657281553398e-05
# Variance: 8.997123721822734e-11
#
#
# TCTPH.4L2.B1
# Position sigma: 4.226518964540211
# Maximum value: 5.4118999999999995e-05
# Spike height: 3.385110185185185e-05
# Variance: 2.7818158492319974e-10
#
#
# TCLA.7L3.B2
# Position sigma: 4.492952376109167
# Maximum value: 7.240000000000001e-07
# Spike height: 1.82623595505618e-07
# Variance: 8.047558183524862e-14
#
#
# TCSG.B5R7.B1
# Position sigma: 2.6947144093087174
# Maximum value: 0.000418291
# Spike height: 0.0004014848811881188
# Variance: 3.3593970724770434e-09
#
#
# TCP.C6R7.B2
# Position sigma: 2.6047042623492724
# Maximum value: 5.9911e-05
# Spike height: 5.248409782608696e-05
# Variance: 9.162653715766875e-11
#
#
# TCSG.E5R7.B1
# Position sigma: 2.2001393879563014
# Maximum value: 5.9368000000000005e-05
# Spike height: 5.584047126436782e-05
# Variance: 3.774984583510641e-11
#
#
# TCLA.A6R7.B1
# Position sigma: 1.5276514174810656
# Maximum value: 2.0272000000000002e-05
# Spike height: 1.8438232323232326e-05
# Variance: 9.733591672772788e-12
#
#
# TCLA.B5R3.B1
# Position sigma: 3.6553216303894502
# Maximum value: 3.9096e-05
# Spike height: 3.494548275862069e-05
# Variance: 2.994044899226306e-11
#
#
# TCSG.B5R7.B1
# Position sigma: 2.694714411081115
# Maximum value: 0.00024634099999999996
# Spike height: 0.00023056109090909086
# Variance: 1.473149510031405e-09
#
#
# TCP.B6L7.B1
# Position sigma: 2.3488750926677673
# Maximum value: 0.0016660999999999998
# Spike height: 0.0016503761511627905
# Variance: 2.361505431687116e-08
#
#
# TCP.D6L7.B1
# Position sigma: 2.266067118285866
# Maximum value: 2.3168000000000002e-05
# Spike height: 2.0185583333333335e-05
# Variance: 8.381972344407785e-12
#
#
# TCP.B6L7.B1
# Position sigma: 2.2311861522693257
# Maximum value: 0.000388245
# Spike height: 0.000374502243902439
# Variance: 3.056714603894273e-09
#
#
# TCSG.5R3.B2
# Position sigma: 3.9207372307252375
# Maximum value: 5.0137e-05
# Spike height: 4.546177e-05
# Variance: 5.5579414841278873e-11
#
#
# TCLA.D6R7.B1
# Position sigma: 5.384389646147129
# Maximum value: 8.1812e-05
# Spike height: 3.737901388888888e-05
# Variance: 7.396673119698207e-10
#
#
# TCSG.B5L3.B2
# Position sigma: 4.726955322924325
# Maximum value: 6.877999999999999e-06
# Spike height: 5.659925925925925e-06
# Variance: 1.3532436309875986e-12
#
#
# TCSP.A4L6.B2
# Position sigma: 2.462135164318248
# Maximum value: 1.1945999999999999e-05
# Spike height: 8.202934782608694e-06
# Variance: 2.9575171877062225e-12
#
#
# TCLA.A7R7.B1
# Position sigma: 2.3297064013024356
# Maximum value: 3.258e-05
# Spike height: 6.987892857142861e-06
# Variance: 2.5909163957759695e-11
#
#
# TCTPH.4R1.B2
# Position sigma: 1.4677252790889144
# Maximum value: 4.5611999999999996e-05
# Spike height: 4.290732051282051e-05
# Variance: 3.240164996117309e-11
#
#
# TCP.C6R7.B2
# Position sigma: 2.70965571687547
# Maximum value: 0.000369964
# Spike height: 0.0003563643181818182
# Variance: 1.4255935423480211e-09
#
#
# TCSG.A4R7.B1
# Position sigma: 3.1259368490895976
# Maximum value: 1.0679e-05
# Spike height: 8.048466666666668e-06
# Variance: 8.329250983032204e-10
#
#
# TCLA.7R3.B1
# Position sigma: 2.483055806344275
# Maximum value: 0.00052852
# Spike height: 0.0005215628709677419
# Variance: 2.7318691426613683e-09
#
#
# TCSG.6R7.B1
# Position sigma: 2.8232925132717237
# Maximum value: 2.1901e-05
# Spike height: 1.6343762376237622e-05
# Variance: 1.3490184165064288e-11
#
#
# TCSG.B5R3.B1
# Position sigma: 6.583036251764775
# Maximum value: 9.55e-07
# Spike height: 2.93625e-07
# Variance: 3.34494318921379e-13
#
#
# TCTPH.4L2.B1
# Position sigma: 5.66840176694152
# Maximum value: 7.74e-07
# Spike height: nan
# Variance: 9.097778868471949e-14
#
#
# TCTPH.4L1.B1
# Position sigma: 1.228120733677947
# Maximum value: 0.00035874199999999995
# Spike height: 0.00035035018181818174
# Variance: 1.4658726951586075e-09
#
#
# TCP.C6L7.B1
# Position sigma: 5.137850714859662
# Maximum value: 6.0453999999999994e-05
# Spike height: 5.887186666666666e-05
# Variance: 2.520669333266015e-11
#
#
# TCP.C6L7.B1
# Position sigma: 4.656028133222638
# Maximum value: 0.00016977799999999999
# Spike height: 0.00016663902352941174
# Variance: 3.0587451839967556e-10
#
#
# TCLA.B6L7.B2
# Position sigma: 8.834015885550293
# Maximum value: 1.448e-05
# Spike height: 1.2036913580246914e-05
# Variance: 7.350045427352371e-12
#
#
# TCLA.B5R3.B1
# Position sigma: 3.883482148294234
# Maximum value: 3.4389999999999996e-06
# Spike height: 2.8188518518518515e-06
# Variance: 3.2567037865513693e-13
#
#
# TCTPV.4L8.B1
# Position sigma: 1.4304617706000817
# Maximum value: 0.000119822
# Spike height: 0.00011306115
# Variance: 1.9784598193036787e-10
#
#
# TCP.D6L7.B1
# Position sigma: 2.507533286627803
# Maximum value: 4.0181999999999996e-05
# Spike height: 3.795110869565217e-05
# Variance: 1.6220346120690633e-11
#
#
# TCSG.A4R7.B1
# Position sigma: 2.3647509264165696
# Maximum value: 0.000695402
# Spike height: 0.0006877963800000001
# Variance: 6.712254884971327e-09
#
#
# TCP.C6L7.B1
# Position sigma: 6.153971608381753
# Maximum value: 1.7738e-05
# Spike height: 1.5128086419753084e-05
# Variance: 1.2492325907697116e-11
#
#
# TCTPV.4L8.B1
# Position sigma: 1.4304617705884035
# Maximum value: 4.2173000000000004e-05
# Spike height: 3.742045714285715e-05
# Variance: 4.261583660416428e-11
#
#
# TCP.D6L7.B1
# Position sigma: 2.748999454942541
# Maximum value: 1.9186e-05
# Spike height: 1.769717857142857e-05
# Variance: 3.423098752190236e-12
#
#
# TCSG.B4L7.B1
# Position sigma: 4.086613248492967
# Maximum value: 1.2851e-05
# Spike height: 8.474247191011235e-06
# Variance: 8.42084991239049e-12
#
#
# TCP.D6L7.B1
# Position sigma: 3.408387837697762
# Maximum value: 4.163e-06
# Spike height: 3.1815283018867923e-06
# Variance: 4.853578782569129e-13
#
#
# TCSG.B5L7.B1
# /Users/gianmarcoricci/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in double_scalars
# Position sigma: 2.859540038783825
# Maximum value: 6.335e-06
# Spike height: -1.870470454545455e-05
# Variance: 4.536145724429404e-10
#
#
# TCTPH.4R8.B2
# Position sigma: 0.7493825672705309
# Maximum value: 3.3666e-05
# Spike height: 3.301912643678161e-05
# Variance: 1.1727101104192755e-11
#
#
# TCSG.5L3.B1
# Position sigma: 8.958245407711994
# Maximum value: 1.0859999999999999e-06
# Spike height: 7.939999999999999e-07
# Variance: 1.1114773793946925e-13
#
#
# TCP.6L3.B1
# Position sigma: 4.011415662622762
# Maximum value: 5.249e-06
# Spike height: 3.613535714285714e-06
# Variance: 3.4654104141540616e-13
#
#
# TCP.B6L7.B1
# Position sigma: 2.858860497905795
# Maximum value: 0.000105885
# Spike height: 9.48070612244898e-05
# Variance: 1.9407472798051537e-10
#
#
# TCP.C6L7.B1
# Position sigma: 4.479518868426718
# Maximum value: 0.000158556
# Spike height: 0.00015676645360824742
# Variance: 2.2175769021489934e-10
#
#
# TCSG.6R7.B1
# Position sigma: 2.1600428437655657
# Maximum value: 5.9368000000000005e-05
# Spike height: 5.043112500000001e-05
# Variance: 3.7944394800546156e-11
#
#
# TCSG.D4L7.B1
# Position sigma: 1.7193630872335508
# Maximum value: 2.1719999999999997e-06
# Spike height: 1.4385124999999997e-06
# Variance: 1.5757590496643516e-13
#
#
# TCSG.4R3.B1
# Position sigma: 2.778134493717344
# Maximum value: 0.000140094
# Spike height: 0.00012233042391304348
# Variance: 1.3718554092091257e-09
#
#
# TCLA.7L3.B2
# Position sigma: 4.150087965805518
# Maximum value: 1.267e-05
# Spike height: 1.0249962962962963e-05
# Variance: 2.422877980515416e-12
#
#
# TCP.C6L7.B1
# Position sigma: 6.153971608381753
# Maximum value: 1.6833e-05
# Spike height: 1.427348148148148e-05
# Variance: 1.1974496436682212e-11
#
#
# TCP.C6R7.B2
# Position sigma: 3.1580846550828174
# Maximum value: 8.633700000000001e-05
# Spike height: 7.915191011235955e-05
# Variance: 1.2808816962006492e-10
#
#
# TCP.D6L7.B1
# Position sigma: 3.6219925250932126
# Maximum value: 7.602e-06
# Spike height: 6.013584158415842e-06
# Variance: 2.5850808759528957e-12
#
#
# TCLA.D6R7.B1
# Position sigma: 7.252944957009391
# Maximum value: 2.1719999999999997e-06
# Spike height: 1.2332799999999996e-06
# Variance: 2.81487722448514e-12
#
#
# TCP.C6L7.B1
# Position sigma: 2.685803116635809
# Maximum value: 0.00148945
# Spike height: 0.00143198793
# Variance: 2.7339288216193652e-08
#
#
# TCTPH.4R2.B2
# Position sigma: 4.1281346868113395
# Maximum value: 0.000482365
# Spike height: 0.00047596567045454547
# Variance: 2.818113087877575e-09
#
#
# TCLA.A5R3.B1
# Position sigma: 5.510414325161668
# Maximum value: 2.715e-06
# Spike height: 2.166825e-06
# Variance: 2.996710545852771e-13
#
#
# TCLA.B6L7.B2
# Position sigma: 9.3193545896239
# Maximum value: 1.3937e-05
# Spike height: 1.2051583333333333e-05
# Variance: 7.2639474390715645e-12
#
#
# TCP.C6L7.B1
# Position sigma: 5.137850714904766
# Maximum value: 8.145e-06
# Spike height: 6.49083962264151e-06
# Variance: 3.4393262722437134e-12
#
#
# TCLA.6R3.B1
# Position sigma: 4.177342356284271
# Maximum value: 5.249e-06
# Spike height: 4.736604395604396e-06
# Variance: 7.064411818773466e-11
#
#
# TCP.C6R7.B2
# Position sigma: 5.3763767462373915
# Maximum value: 1.0136000000000001e-05
# Spike height: 7.854915887850468e-06
# Variance: 4.3938631359654085e-12
#
#
# TCTPH.4R8.B2
# Position sigma: 0.008234973266711652
# Maximum value: 7.059e-06
# Spike height: 6.55525e-06
# Variance: 2.4074412498293322e-12
#
#
# TCTPH.4L1.B1
# Position sigma: 1.4682044855272058
# Maximum value: 4.163e-06
# Spike height: 3.4834601769911502e-06
# Variance: 7.193824585277046e-13
#
#
# TCP.D6L7.B1
# Position sigma: 2.6468406914404583
# Maximum value: 2.2625e-05
# Spike height: 2.084927848101266e-05
# Variance: 6.872278367135066e-12
#
#
# TCTPV.4L1.B1
# Position sigma: 2.314057130445937
# Maximum value: 7.059e-06
# Spike height: 5.6621847826086955e-06
# Variance: 8.10732048099897e-13
#
#
# TCSG.A5L3.B2
# Position sigma: 5.863693775410925
# Maximum value: 1.2851e-05
# Spike height: 1.135130588235294e-05
# Variance: 2.772304498435542e-12
#
#
# TCP.C6L7.B1
# Position sigma: 5.004276137736972
# Maximum value: 0.00014950600000000001
# Spike height: 0.0001473210430107527
# Variance: 2.615322431041923e-10
#
#
# TCSG.D5R7.B1
# Position sigma: 2.6046811511766315
# Maximum value: 4.887e-05
# Spike height: 4.7553970588235295e-05
# Variance: 4.3594025842075303e-11
#
#
# TCLA.B6R7.B1
# Position sigma: 2.7700441698813476
# Maximum value: 1.2308e-05
# Spike height: 6.054196261682243e-06
# Variance: 5.706303450449428e-12
#
#
# TCLA.6L3.B2
# Position sigma: 3.673201631119368
# Maximum value: 1.2670000000000001e-06
# Spike height: 4.784402173913046e-07
# Variance: 8.377754406075789e-14
#
#
# TCSG.6R7.B1
# Position sigma: 2.1600428437655657
# Maximum value: 3.4751999999999995e-05
# Spike height: 2.7769658823529407e-05
# Variance: 1.7510859801883026e-11
#
#
# TCSG.A5L7.B1
# Position sigma: 1.9033521784614793
# Maximum value: 0.00019005
# Spike height: 0.0001755002168674699
# Variance: 5.745172667890545e-10
#
#
# TCP.C6R7.B2
# Position sigma: 2.4902117679735833
# Maximum value: 0.000145705
# Spike height: 0.00013547750549450547
# Variance: 3.023227946253273e-10
#
#
# TCP.C6L7.B1
# Position sigma: 3.8879743110158556
# Maximum value: 0.000122356
# Spike height: 0.00011658411111111112
# Variance: 1.3731004725816363e-10
#
#
# TCSG.A5L7.B1
# Position sigma: 1.8550787544245864
# Maximum value: 0.000504085
# Spike height: 0.000487777670212766
# Variance: 3.793881864649563e-09
#
#
# TCLA.B5L3.B2
# Position sigma: 3.8407210496336166
# Maximum value: 1.81e-06
# Spike height: 1.1522916666666666e-06
# Variance: 2.633166688758672e-13
#
#
# TCSG.A4L7.B1
# Position sigma: 3.7986072381093825
# Maximum value: 5.0680000000000004e-06
# Spike height: 3.7081764705882355e-06
# Variance: 5.622822893105012e-13
#
#
# TCSG.5L3.B1
# Position sigma: 4.681099058982642
# Maximum value: 6.335e-06
# Spike height: 4.827989898989899e-06
# Variance: 6.334776665149619e-13
#
#
# TCP.B6L7.B1
# Position sigma: 2.1821490935987633
# Maximum value: 0.00035258800000000003
# Spike height: 0.0003360255268817205
# Variance: 1.5347966570013368e-09
#
#
# TCTPH.4R2.B2
# Position sigma: 4.1281346868113395
# Maximum value: 0.00023548099999999998
# Spike height: 0.0002309660588235294
# Variance: 1.4617789733365582e-09
#
#
# TCSG.B5L3.B2
# Position sigma: 3.8943173202314396
# Maximum value: 1.5204e-05
# Spike height: 1.0461800000000002e-05
# Variance: 3.0650638438957763e-12
#
#
# TCP.C6R7.B2
# Position sigma: 3.2248719436171043
# Maximum value: 3.2399e-05
# Spike height: 2.9126358024691357e-05
# Variance: 1.7763928029241088e-11
#
#
# TCSG.4L3.B2
# Position sigma: 2.81242077314357
# Maximum value: 1.991e-05
# Spike height: 1.830080612244898e-05
# Variance: 4.248316267920125e-12
#
#
# TCSG.E5R7.B1
# Position sigma: 2.200139387939028
# Maximum value: 4.3078e-05
# Spike height: 4.0533e-05
# Variance: 3.801866265271933e-11
#
#
# TCP.6L3.B1
# Position sigma: 4.919853306321047
# Maximum value: 2.353e-06
# Spike height: 1.6980714285714288e-06
# Variance: 2.548169233900329e-12
#
#
# TCTPV.4L8.B1
# Position sigma: 1.347295388588449
# Maximum value: 6.316899999999999e-05
# Spike height: 5.673841573033707e-05
# Variance: 1.1174343125779388e-10
#
#
# TCLA.A6R7.B1
# Position sigma: 1.4898538566361734
# Maximum value: 0.000106609
# Spike height: 0.00010193246511627907
# Variance: 7.847872668935601e-11
#
#
# TCP.C6R7.B2
# Position sigma: 2.3948013558926906
# Maximum value: 0.00051223
# Spike height: 0.0004987061058823529
# Variance: 2.1548978649032885e-09
#
#
# TCTPH.4R1.B2
# Position sigma: 1.5037430773487652
# Maximum value: 2.4616e-05
# Spike height: 2.108628888888889e-05
# Variance: 1.0976124219905561e-11
#
#
# TCSG.A6L7.B1
# Position sigma: 3.4687767438742556
# Maximum value: 6.4255e-05
# Spike height: 5.475455681818182e-05
# Variance: 5.4874465328108976e-11
#
#
# TCP.C6L7.B1
# Position sigma: 3.487250578111251
# Maximum value: 0.00031675
# Spike height: 0.0003105250196078431
# Variance: 9.237495864290592e-10
#
#
# TCLA.B5R3.B1
# Position sigma: 3.807428642325587
# Maximum value: 8.145e-06
# Spike height: 6.667636363636364e-06
# Variance: 9.062067325065426e-13
#
#
# TCTPH.4L5.B1
# Position sigma: 0.7765889182565979
# Maximum value: 0.0005663490000000001
# Spike height: 0.0005651976292134832
# Variance: 2.1783513216183877e-09
#
#
# TCTPH.4L8.B1
# Position sigma: 5.052274673590016
# Maximum value: 0.00496972
# Spike height: 0.004910430209876544
# Variance: 2.0481658072144778e-07
#
#
# TCTPV.4L5.B1
# Position sigma: 3.62921207653561
# Maximum value: 1.6790000000000001e-06
# Spike height: 1.0289893617021277e-06
# Variance: 8.297732199340082e-14
#
#
# TCP.C6L7.B1
# Position sigma: 3.5635789401433606
# Maximum value: 0.0008894339999999999
# Spike height: 0.0008702205757575757
# Variance: 5.361020807816451e-09
#
#
# TCTPV.4L2.B1
# Position sigma: 2.1444973754156345
# Maximum value: 3.6380999999999996e-05
# Spike height: 3.552255434782608e-05
# Variance: 1.481913271962112e-11
#
#
# TCLA.7R3.B1
# Position sigma: 2.9682506198678382
# Maximum value: 9.285299999999999e-05
# Spike height: 9.24778148148148e-05
# Variance: 6.770662333220491e-11
# TCP.6L3.B1
# Position sigma: 3.9297583463352757
# Maximum value: 7.964e-06
# Spike height: 6.2862531645569625e-06
# Variance: 7.938608869040843e-13
#
#
# TCSG.A5L3.B2
# Position sigma: 6.469608799453829
# Maximum value: 1.81e-06
# Spike height: 9.76123287671233e-07
# Variance: 1.6073634816247584e-13
#
#
# TCLA.6L3.B2
# Position sigma: 3.1073022201527034
# Maximum value: 3.982e-06
# Spike height: 3.1991290322580645e-06
# Variance: 2.409422812492887e-12
#
#
# TCP.C6R7.B2
# Position sigma: 5.929757138929084
# Maximum value: 1.3032e-05
# Spike height: 1.0311457943925233e-05
# Variance: 5.68451928942428e-12
#
#
# TCSG.5R3.B2
# Position sigma: 3.9207372307252375
# Maximum value: 3.0408e-05
# Spike height: 2.6224195402298852e-05
# Variance: 1.2469584336557049e-11
#
#
# TCTPV.4L2.B1
# Position sigma: 5.661473071093158
# Maximum value: 1.8100000000000003e-05
# Spike height: 1.7782943820224724e-05
# Variance: 9.437931378626697e-12
#
#
# TCP.C6L7.B1
# Position sigma: 2.6285568652476727
# Maximum value: 0.00020815
# Spike height: 0.000132032688172043
# Variance: 2.959578776586187e-09
#
#
# TCLA.C6R7.B1
# Position sigma: 7.200506587320128
# Maximum value: 1.629e-05
# Spike height: 1.2776337500000001e-05
# Variance: 1.0535007029553987e-11
#
#
# TCP.C6L7.B1
# Position sigma: 6.106266402115228
# Maximum value: 1.6833e-05
# Spike height: 1.4069121951219512e-05
# Variance: 1.3784025234839001e-11
#
#
# TCP.B6L7.B1
# Position sigma: 4.776209475360234
# Maximum value: 1.2851e-05
# Spike height: 1.107654716981132e-05
# Variance: 6.046160158379795e-12
#
#
# TCSG.D4L7.B1
# Position sigma: 1.260119526504086
# Maximum value: 3.4209000000000004e-05
# Spike height: 3.163405952380953e-05
# Variance: 1.038637016008647e-11
#
#
# TCLA.A5R3.B1
# Position sigma: 5.147629040372759
# Maximum value: 1.6833e-05
# Spike height: 1.417654e-05
# Variance: 9.261310336670846e-12
#
#
# TCSG.A5R3.B1
# Position sigma: 4.48572823793883
# Maximum value: 5.5023999999999994e-05
# Spike height: 5.0869227272727266e-05
# Variance: 5.2120544319831595e-11
#
#
# TCTPH.4L8.B1
# Position sigma: 6.705746388854101
# Maximum value: 7.74e-07
# Spike height: -7.609016393442619e-07
# Variance: 3.582001321509844e-12
#
#
# TCLA.A7L7.B2
# Position sigma: 3.111336362482309
# Maximum value: 0.000182267
# Spike height: 0.00015438079775280898
# Variance: 4.244575573460864e-10
#
#
# TCLA.B5R3.B1
# Position sigma: 3.7313751363533396
# Maximum value: 2.3891999999999998e-05
# Spike height: 2.1029715686274507e-05
# Variance: 5.69725307975879e-12
#
#
# TCTPH.4R1.B2
# Position sigma: 1.7198498668814877
# Maximum value: 5.792000000000001e-06
# Spike height: 5.4114536082474235e-06
# Variance: 1.0360868970303793e-12
#
#
# TCLA.D6L7.B2
# Position sigma: 2.211282773616312
# Maximum value: 2.1901e-05
# Spike height: 1.76588125e-05
# Variance: 1.8043688261918304e-11
#
#
# TCTPV.4L8.B1
# Position sigma: 1.5635279818044479
# Maximum value: 4.0725e-05
# Spike height: 3.910326923076923e-05
# Variance: 3.0417256205825487e-11
#
#
# TCP.C6L7.B1
# Position sigma: 3.487250579288677
# Maximum value: 4.5974e-05
# Spike height: 3.4982775e-05
# Variance: 7.938745398370127e-11
#
#
# TCSG.A4L7.B1
# Position sigma: 2.6330771336853935
# Maximum value: 3.2037e-05
# Spike height: 2.642207216494845e-05
# Variance: 2.7820305245761753e-11
#
#
# TCSG.B5R3.B1
# Position sigma: 5.40346717276378
# Maximum value: 1.3575e-05
# Spike height: 1.245786075949367e-05
# Variance: 3.1338994220047756e-12
#
#
# TCLA.B5L3.B2
# Position sigma: 3.4034112271390855
# Maximum value: 2.0996e-05
# Spike height: 1.658542528735632e-05
# Variance: 9.274053323330304e-12
#
#
# TCP.B6L7.B1
# Position sigma: 2.5352159142155233
# Maximum value: 0.0007174839999999999
# Spike height: 0.0007035285306122448
# Variance: 5.647130198824522e-09
#
#
# TCSG.A4R7.B1
# Position sigma: 2.248035750775701
# Maximum value: 0.0005611
# Spike height: 0.0005429059509803922
# Variance: 5.3909591805910535e-09
#
#
# TCP.C6L7.B1
# Position sigma: 4.021548894003529
# Maximum value: 0.00024670299999999997
# Spike height: 0.00024081706329113922
# Variance: 6.085757937961944e-10
#
#
# TCLA.B6R7.B1
# Position sigma: 2.9484369965365698
# Maximum value: 1.448e-05
# Spike height: 9.635289719626169e-06
# Variance: 3.7191162044316806e-12
#
#
# TCP.D6L7.B1
# Position sigma: 4.021340418885542
# Maximum value: 6.516e-06
# Spike height: 4.957756097560975e-06
# Variance: 1.0524333494993747e-12
#
#
# TCP.C6L7.B1
# Position sigma: 3.6399072462765627
# Maximum value: 0.000559833
# Spike height: 0.000550769425
# Variance: 3.487026690603368e-09
#
#
# TCLA.A6R7.B1
# Position sigma: 1.489853856845898
# Maximum value: 8.651799999999999e-05
# Spike height: 8.083233749999998e-05
# Variance: 6.562976482884855e-11
#
#
# TCTPH.4R8.B2
# Position sigma: 0.6670328346034397
# Maximum value: 3.258e-05
# ...
# Maximum value: 9.231e-06
# Spike height: 7.830833333333333e-06
# Variance: 1.2210900653089087e-12
#
#
# TCSG.A4L7.B1
# Position sigma: 4.538761391998832
# Maximum value: 4.163e-06
# Spike height: -5.496117647058831e-07
# Variance: 3.3316262189640515e-11
#
#
# TCP.D6L7.B1
# Position sigma: 2.163908354756585
# Maximum value: 5.2671000000000004e-05
# Spike height: 4.9756625000000006e-05
# Variance: 3.746937362029244e-11
#
#
# TCTPH.4L5.B1
# Position sigma: 0.862347203361019
# Maximum value: 1.448e-05
# Spike height: 1.4142186046511628e-05
# Variance: 3.1166554528046423e-11
#
#
# TCP.C6R7.B2
# Position sigma: 3.8784332694685
# Maximum value: 1.4118e-05
# Spike height: 1.1310956043956043e-05
# Variance: 1.3971728240385717e-11
#
#
# TCTPH.4R1.B2
# Position sigma: 1.4677252790889144
# Maximum value: 2.5702e-05
# Spike height: 2.236134736842105e-05
# Variance: 1.535830052232906e-11
#
#
# TCSP.A4L6.B2
# Position sigma: 2.510083268750824
# Maximum value: 5.611e-06
# Spike height: 3.826900000000001e-06
# Variance: 1.2985019447036085e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.2707678190716964
# Maximum value: 0.0009498880000000001
# Spike height: 0.0009389623875000001
# Variance: 5.658232677701757e-09
#
#
# TCSG.6L7.B2
# Position sigma: 2.9699154671627475
# Maximum value: 6.697e-05
# Spike height: 6.11180566037736e-05
# Variance: 8.614047306277725e-11
#
#
# TCP.C6R7.B2
# Position sigma: 3.735317650951429
# Maximum value: 9.3939e-05
# Spike height: 8.903691666666666e-05
# Variance: 8.228051325884631e-11
#
#
# TCLA.6R3.B1
# Position sigma: 3.9304058563695574
# Maximum value: 0.000496845
# Spike height: 0.00048753702298850576
# Variance: 3.021596505111276e-09
#
#
# TCSG.E5R7.B1
# Position sigma: 4.366326007545663
# Maximum value: 2.715e-06
# Spike height: -1.2246338028169016e-06
# Variance: 1.8207650420155918e-11
#
#
# TCTPH.4R5.B2
# Position sigma: 5.1540664442552915
# Maximum value: 0.000208331
# Spike height: 0.00019927903260869565
# Variance: 1.0089850904484015e-09
#
#
# TCTPH.4L1.B1
# Position sigma: 5.106396732682672
# Maximum value: 1.86e-06
# Spike height: 1.510752808988764e-06
# Variance: 1.5983177480373214e-13
#
#
# TCLA.C6R7.B1
# Position sigma: 7.392179344921508
# Maximum value: 9.05e-06
# Spike height: 7.41516037735849e-06
# Variance: 2.3955712352656724e-12
#
#
# TCP.C6R7.B2
# Position sigma: 3.792563898188755
# Maximum value: 4.525e-05
# Spike height: 4.185830681818182e-05
# Variance: 5.324068704343497e-11
#
#
# TCTPH.4R8.B2
# Position sigma: 0.6670328346034397
# Maximum value: 2.0090999999999998e-05
# Spike height: 1.9504542168674696e-05
# Variance: 2.8948554195869905e-12
#
#
# TCP.B6L7.B1
# Position sigma: 2.1233046256254786
# Maximum value: 0.0005670730000000001
# Spike height: 0.0005521662210526317
# Variance: 3.3399286450782783e-09
#
#
# TCTPH.4R8.B2
# Position sigma: 1.5234700543062143
# Maximum value: 0.00023747200000000002
# Spike height: 0.0002347315980392157
# Variance: 5.429001634983218e-10
#
#
# TCP.D6L7.B1
# Position sigma: 2.9440298216783294
# Maximum value: 1.7919000000000002e-05
# Spike height: 1.6521440476190478e-05
# Variance: 3.0326488180680457e-12
#
#
# TCP.C6L7.B1
# Position sigma: 4.021548889658488
# Maximum value: 0.00019385099999999998
# Spike height: 0.00018885227160493826
# Variance: 5.443185542120831e-10
#
#
# TCTPH.4L2.B1
# Position sigma: 4.550942595080235
# Maximum value: 2.5340000000000002e-06
# Spike height: 2.1702470588235297e-06
# Variance: 1.0071909992120831e-11
#
#
# TCP.C6R7.B2
# Position sigma: 5.5576565300501874
# Maximum value: 1.1765e-05
# Spike height: 9.01562962962963e-06
# Variance: 5.738217195812948e-12
#
#
# TCTPH.4R2.B2
# Position sigma: 4.476500483395525
# Maximum value: 6.335e-06
# Spike height: 5.973189873417722e-06
# Variance: 5.0804871351547394e-11
#
#
# TCSG.B5L3.B2
# Position sigma: 3.9637038207877233
# Maximum value: 1.3937e-05
# Spike height: 1.1733793103448276e-05
# Variance: 3.972698048782569e-12
#
#
# TCTPV.4L1.B1
# Position sigma: 5.5155233255659875
# Maximum value: 8.326e-06
# Spike height: 7.993756097560975e-06
# Variance: 5.690871255831163e-13
#
#
# TCLA.B6R7.B1
# Position sigma: 2.7700441698813476
# Maximum value: 1.1765e-05
# Spike height: 6.8035700934579435e-06
# Variance: 3.1172814635055175e-12
#
#
# TCSG.A6L7.B1
# Position sigma: 4.6173783049458645
# Maximum value: 3.6562e-05
# Spike height: 7.584063063063059e-06
# Variance: 1.3500202306653771e-09
#
#
# TCTPH.4R2.B2
# Position sigma: 5.103558916869486
# Maximum value: 5.429999999999999e-07
# Spike height: 2.1048044692737417e-07
# Variance: 2.1035455085902802e-14
#
#
# TCLA.6R3.B1
# Position sigma: 3.8480936918382582
# Maximum value: 0.00043928699999999996
# Spike height: 0.0004262745196078431
# Variance: 3.469734559586303e-09
#
#
# TCLA.B5R3.B1
# Position sigma: 3.6553216303894502
# Maximum value: 2.0272000000000002e-05
# Spike height: 1.6426673469387756e-05
# Variance: 7.376872162930937e-12
#
#
# TCLA.A6R7.B1
# Position sigma: 1.4898538566361734
# Maximum value: 0.000119279
# Spike height: 0.00011481665384615383
# Variance: 2.039474001439018e-10
#
#
# TCP.C6L7.B1
# Position sigma: 4.751438545788677
# Maximum value: 0.000127424
# Spike height: 0.0001244690752688172
# Variance: 1.5643388654053366e-10
#
#
# TCLA.A5R3.B1
# Position sigma: 5.147629040372759
# Maximum value: 2.3891999999999998e-05
# Spike height: 2.1521393258426965e-05
# Variance: 1.1123522334139256e-11
#
#
# TCP.C6L7.B1
# Position sigma: 2.5522285366585447
# Maximum value: 0.00138248
# Spike height: 0.0013491259361702128
# Variance: 3.90495566534999e-08
# TCP.D6L7.B1
# Position sigma: 3.677715487017724
# Maximum value: 5.249e-06
# Spike height: 3.901625e-06
# Variance: 1.062059693821823e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.9386407070339606
# Maximum value: 0.000272224
# Spike height: 0.0002629584269662921
# Variance: 1.3941756249998868e-09
#
#
# TCSG.6L7.B2
# Position sigma: 2.9948727395638697
# Maximum value: 5.0137e-05
# Spike height: 4.777835106382978e-05
# Variance: 4.5963698531687416e-11
#
#
# TCP.C6L7.B1
# Position sigma: 4.751438544505266
# Maximum value: 0.0003258
# Spike height: 0.0003236746913580247
# Variance: 1.0064235062692848e-09
#
#
# TCSG.A5R3.B1
# Position sigma: 4.798458748881225
# Maximum value: 4.343999999999999e-06
# Spike height: 3.8100833333333326e-06
# Variance: 1.3453951153430425e-12
#
#
# TCP.6L3.B1
# Position sigma: 4.133901637053992
# Maximum value: 6.6970000000000004e-06
# Spike height: 5.621758620689656e-06
# Variance: 9.540772044601216e-13
#
#
# TCTPH.4L1.B1
# Position sigma: 1.228120733206987
# Maximum value: 0.000125252
# Spike height: 0.00012175704938271606
# Variance: 2.571709511035102e-10
#
#
# TCLA.B5L3.B2
# Position sigma: 3.4034112271321884
# Maximum value: 2.534e-05
# Spike height: 1.9852653465346537e-05
# Variance: 7.696479219820231e-12
#
#
# TCP.C6R7.B2
# Position sigma: 6.006085468955525
# Maximum value: 1.1584000000000001e-05
# Spike height: 8.971542056074767e-06
# Variance: 5.4870884250768015e-12
#
#
# TCTPV.4L1.B1
# Position sigma: 3.7746730072580164
# Maximum value: 3.077e-06
# Spike height: 2.70990243902439e-06
# Variance: 2.0914953450335644e-13
#
#
# TCSG.A5L3.B2
# Position sigma: 6.293697986175629
# Maximum value: 2.5340000000000002e-06
# Spike height: 1.7896534653465348e-06
# Variance: 2.7829581712936627e-13
#
#
# TCSG.6R7.B1
# Position sigma: 3.4447156273040185
# Maximum value: 1.3213e-05
# Spike height: 6.583112359550562e-06
# Variance: 2.1287801650102413e-11
#
#
# TCSG.5R3.B2
# Position sigma: 3.9841026782481936
# Maximum value: 4.0725e-05
# Spike height: 3.335077108433735e-05
# Variance: 4.306140153453175e-11
#
#
# TCLA.B5R3.B1
# Position sigma: 3.7313751363533396
# Maximum value: 1.2851e-05
# Spike height: 1.0685961538461537e-05
# Variance: 3.0381689974684275e-12
#
#
# TCLA.6L3.B2
# Position sigma: 3.0455677389229634
# Maximum value: 2.4978e-05
# Spike height: 1.94959625e-05
# Variance: 1.0701238632239174e-11
#
#
# TCTPV.4L1.B1
# Position sigma: 2.1357261222489448
# Maximum value: 5.1766000000000005e-05
# Spike height: 4.756711000000001e-05
# Variance: 2.939679895081922e-11
#
#
# TCTPH.4R5.B2
# Position sigma: 5.18676472304
# Maximum value: 6.878e-05
# Spike height: 6.0687876404494383e-05
# Variance: 1.3078607189031756e-10
#
#
# TCSG.B5R3.B1
# Position sigma: 6.236104169985341
# Maximum value: 3.077e-06
# Spike height: 2.5464356435643566e-06
# Variance: 2.425018842587322e-13
#
#
# TCP.C6L7.B1
# Position sigma: 3.7353176506991925
# Maximum value: 0.00025702
# Spike height: 0.000251429
# Variance: 5.427965785393959e-10
#
#
# TCLA.B6R7.B1
# Position sigma: 4.028704669176259
# Maximum value: 7.964e-06
# Spike height: 5.857812500000001e-06
# Variance: 1.4831047269313937e-12
#
#
# TCP.C6R7.B2
# Position sigma: 2.3948013554075454
# Maximum value: 0.000302089
# Spike height: 0.00029469276842105264
# Variance: 1.1523414628010867e-09
#
#
# TCLA.C6R7.B1
# Position sigma: 7.226062954976988
# Maximum value: 1.8462e-05
# Spike height: 1.4783175e-05
# Variance: 1.0559720356439865e-11
#
#
# TCSG.A6L7.B1
# Position sigma: 3.4687767438742556
# Maximum value: 0.000225345
# Spike height: 0.00021534236842105263
# Variance: 3.6761492247841037e-10
#
#
# TCP.B6L7.B1
# Position sigma: 4.766402063670651
# Maximum value: 1.1402999999999999e-05
# Spike height: 9.540267857142857e-06
# Variance: 6.015813160399359e-12
#
#
# TCSG.A4R7.B1
# Position sigma: 2.3647509251952075
# Maximum value: 0.000320008
# Spike height: 0.0003173117234042553
# Variance: 1.972943043351347e-09
#
#
# TCLA.7L3.B2
# Position sigma: 4.264376102602817
# Maximum value: 4.525e-06
# Spike height: 4.037666666666667e-06
# Variance: 3.3160611400614455e-13
#
#
# TCP.C6L7.B1
# Position sigma: 5.71031319005294
# Maximum value: 6.6970000000000004e-06
# Spike height: 5.626913580246914e-06
# Variance: 1.56240188539652e-12
#
#
# TCTPH.4L8.B1
# Position sigma: 5.125762308074912
# Maximum value: 0.000140818
# Spike height: 0.00014044142696629212
# Variance: 1.0809706793321514e-08
#
#
# TCSP.A4R6.B1
# Position sigma: 4.239592287275775
# Maximum value: 7.167600000000001e-05
# Spike height: 6.78383417721519e-05
# Variance: 9.168615479721813e-11
#
#
# TCTPH.4L5.B1
# Position sigma: 0.6813019352574836
# Maximum value: 0.000180638
# Spike height: 0.00017826465432098766
# Variance: 3.624235569436798e-10
#
#
# TCSG.B4L7.B1
# Position sigma: 4.676737905315056
# Maximum value: 4.525e-05
# Spike height: 4.054433333333334e-05
# Variance: 2.9988577443622685e-11
#
#
# TCSG.5L3.B1
# Position sigma: 4.839511886924869
# Maximum value: 4.163e-06
# Spike height: 3.5917980769230765e-06
# Variance: 7.770888140857892e-13
#
#
# TCSG.B5R3.B1
# Position sigma: 5.854478879667362
# Maximum value: 1.5566e-05
# Spike height: 1.3607871287128712e-05
# Variance: 5.54258828908295e-12
#
#
# TCSP.A4L6.B2
# Position sigma: 2.380623387967021
# Maximum value: 9.104299999999999e-05
# Spike height: 7.854988636363635e-05
# Variance: 1.486185078011151e-10
#
#
# TCP.D6L7.B1
# Position sigma: 3.1019115471311105
# Maximum value: 1.2127000000000001e-05
# Spike height: 1.107747311827957e-05
# Variance: 1.9232863094777578e-12
#
#
# TCP.C6L7.B1
# Position sigma: 6.106266402115228
# Maximum value: 1.7557e-05
# Spike height: 1.4936219512195124e-05
# Variance: 1.2532931610763437e-11
#
#
# TCP.D6L7.B1
# Position sigma: 2.507533286627803
# Maximum value: 2.5702e-05
# Spike height: 2.3615155555555555e-05
# Variance: 7.790531663983394e-12
#
#
# TCSG.A5R3.B1
# Position sigma: 4.485728238632707
# Maximum value: 4.8688999999999994e-05
# Spike height: 4.518398823529411e-05
# Variance: 4.213855109622824e-11
#
#
# TCTPV.4L8.B1
# Position sigma: 3.193589069215966
# Maximum value: 1.0859999999999999e-06
# Spike height: 7.166339285714284e-07
# Variance: 4.566184469222893e-14
#
#
# TCP.C6R7.B2
# Position sigma: 2.70965571687547
# Maximum value: 6.6608e-05
# Spike height: 5.596315094339622e-05
# Variance: 1.3112509176868822e-10
#
#
# TCP.C6L7.B1
# Position sigma: 3.4872505780327563
# Maximum value: 8.452700000000001e-05
# Spike height: 6.511798214285715e-05
# Variance: 2.491326888288772e-10
#
#
# TCSP.A4R6.B1
# Position sigma: 4.292653516853684
# Maximum value: 1.3937e-05
# Spike height: 1.3410182926829268e-05
# Variance: 3.532336468449199e-11
#
#
# TCP.D6L7.B1
# Position sigma: 3.408387837715921
# Maximum value: 9.05e-06
# Spike height: 7.903515789473685e-06
# Variance: 1.3935027990670153e-12
#
#
# TCSG.A4R7.B1
# Position sigma: 2.2480357411000305
# Maximum value: 0.0005245380000000001
# Spike height: 0.0005084251075268818
# Variance: 4.430422764324154e-09
#
#
# TCP.C6R7.B2
# Position sigma: 5.3763767462373915
# Maximum value: 1.1945999999999999e-05
# Spike height: 9.7494125e-06
# Variance: 4.385992862071912e-12
#
#
# TCTPV.4L2.B1
# Position sigma: 2.0930294384056594
# Maximum value: 1.1765e-05
# Spike height: 9.7005e-06
# Variance: 5.342191295340768e-12
#
#
# TCLA.D6R7.B1
# Position sigma: 5.3843896365382236
# Maximum value: 0.00011421100000000001
# Spike height: 9.188435164835165e-05
# Variance: 4.5741849300634286e-10
#
#
# TCSG.5L3.B1
# Position sigma: 4.586051361585024
# Maximum value: 2.4616e-05
# Spike height: 1.9431642857142855e-05
# Variance: 6.564078611531447e-12
#
#
# TCP.C6L7.B1
# Position sigma: 3.143773094050941
# Maximum value: 0.0006854469999999999
# Spike height: 0.0006786928421052631
# Variance: 3.9311853589622274e-09
#
#
# TCLA.7L3.B2
# Position sigma: 4.150087965805518
# Maximum value: 2.8055e-05
# Spike height: 2.5982782051282053e-05
# Variance: 5.708922951274321e-12
#
#
# TCP.C6L7.B1
# Position sigma: 6.153971608381753
# Maximum value: 1.7919000000000002e-05
# Spike height: 1.5347594339622643e-05
# Variance: 1.2068284786978045e-11
#
#
# TCP.C6R7.B2
# Position sigma: 3.6542188000158315
# Maximum value: 5.068e-05
# Spike height: 4.780285416666667e-05
# Variance: 2.6908887920923868e-11
#
#
# TCTPV.4L1.B1
# Position sigma: 2.314057130445937
# Maximum value: 1.6109e-05
# Spike height: 1.4097424528301888e-05
# Variance: 7.63007857435431e-12
#
#
# TCLA.A5R3.B1
# Position sigma: 6.177154848490837
# Maximum value: 1.0859999999999999e-06
# Spike height: 6.391944444444442e-07
# Variance: 5.193205302082162e-14
#
#
# TCSG.D4L7.B1
# Position sigma: 2.357823647313762
# Maximum value: 1.498e-06
# Spike height: 5.459230769230771e-07
# Variance: 1.6487148344521535e-13
#
#
# TCLA.B6L7.B2
# Position sigma: 8.484912612566871
# Maximum value: 0.000581734
# Spike height: 0.0005604080759493671
# Variance: 2.8270761339705075e-09
#
#
# TCP.D6L7.B1
# Position sigma: 2.163908354756585
# Maximum value: 4.3621e-05
# Spike height: 4.1725731707317076e-05
# Variance: 1.764502569427693e-11
# TCTPH.4L2.B1
# Position sigma: 4.262566031079275
# Maximum value: 0.000939571
# Spike height: 0.0009285916206896553
# Variance: 8.444613660611537e-09
#
#
# TCLA.B5L3.B2
# Position sigma: 3.48897184458879
# Maximum value: 5.43e-06
# Spike height: 4.436148936170212e-06
# Variance: 3.339872422118554e-12
#
#
# TCLA.6R3.B1
# Position sigma: 3.8480936918382582
# Maximum value: 0.000492139
# Spike height: 0.0004706108600000001
# Variance: 2.737424533629166e-09
#
#
# TCTPH.4R2.B2
# Position sigma: 4.215226135978529
# Maximum value: 0.00036181900000000004
# Spike height: 0.0003576002073170732
# Variance: 1.2353807608821263e-09
#
#
# TCSG.B5L3.B2
# Position sigma: 3.894317320642643
# Maximum value: 2.7693e-05
# Spike height: 2.4628482758620692e-05
# Variance: 2.396046128842867e-11
#
#
# TCP.C6L7.B1
# Position sigma: 3.8879743110158556
# Maximum value: 0.000284532
# Spike height: 0.0002794489166666667
# Variance: 8.000136079342364e-10
#
#
# TCSG.4R3.B1
# Position sigma: 2.7781346110507883
# Maximum value: 6.534100000000001e-05
# Spike height: 6.298236585365854e-05
# Variance: 1.188592260779156e-09
#
#
# TCP.B6L7.B1
# Position sigma: 2.2311861527428682
# Maximum value: 0.000301184
# Spike height: 0.000286596170212766
# Variance: 9.550792701179607e-10
#
#
# TCSG.D5R7.B1
# Position sigma: 2.5732994510843223
# Maximum value: 0.000223897
# Spike height: 0.00021998936170212766
# Variance: 6.861469844718394e-10
#
#
# TCSP.A4L6.B2
# Position sigma: 2.5868002358766398
# Maximum value: 2.715e-06
# Spike height: 1.9112345679012343e-06
# Variance: 5.672092118557288e-13
#
#
# TCSG.A5L7.B1
# Position sigma: 1.8550787536454274
# Maximum value: 0.000211951
# Spike height: 0.00019792250549450547
# Variance: 1.7493212138161325e-09
#
#
# TCSG.B5L7.B1
# Position sigma: 1.870764091443887
# Maximum value: 0.00038788300000000005
# Spike height: 0.00036579489887640453
# Variance: 4.056158847982108e-09
#
#
# TCSG.6L7.B2
# Position sigma: 2.938718877635676
# Maximum value: 0.000111496
# Spike height: 0.00010525952380952382
# Variance: 1.5242535522835362e-10
#
#
# TCP.C6L7.B1
# Position sigma: 2.666721030260343
# Maximum value: 0.00022914599999999998
# Spike height: 0.00015992254999999998
# Variance: 2.469508452744424e-09
#
#
# TCP.C6R7.B2
# Position sigma: 3.2248719436171043
# Maximum value: 2.6606999999999998e-05
# Spike height: 2.2680182926829266e-05
# Variance: 1.2554876998065752e-11
#
#
# TCTPH.4L2.B1
# Position sigma: 4.262566031079275
# Maximum value: 0.00286197
# Spike height: 0.0028508011414141417
# Variance: 9.390824791753157e-08
#
#
# TCP.C6L7.B1
# Position sigma: 2.7239672787603757
# Maximum value: 0.0009933280000000001
# Spike height: 0.0009802334320987655
# Variance: 1.128114118269918e-08
